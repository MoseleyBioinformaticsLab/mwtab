# %% [raw]
# The mwtab Tutorial
# ==================
#
# The :mod:`mwtab` package provides classes and other facilities for parsing,
# accessing, and manipulating data stored in ``mwTab`` and ``JSON`` representation
# of ``mwTab`` formats.
#
# Also, the :mod:`mwtab` package provides simple command-line interface to convert
# between ``mwTab`` and its ``JSON`` representation as well as validate consistency
# of the files.

# %% [raw]
# Brief mwTab Format Overview
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# .. note::
#
#    For full official specification see the following link (``mwTab file specification``):
#    http://www.metabolomicsworkbench.org/data/tutorials.php
#
#
# The ``mwTab`` formatted files consist of multiple blocks. Each new block starts with ``#``.
#
# * Some of the blocks contain only "key-value"-like pairs.
#
# .. code-block:: none
#
#    #METABOLOMICS WORKBENCH STUDY_ID:ST000001 ANALYSIS_ID:AN000001
#    VERSION             	1
#    CREATED_ON          	2016-09-17
#    #PROJECT
#    PR:PROJECT_TITLE                 	FatB Gene Project
#    PR:PROJECT_TYPE                  	Genotype treatment
#    PR:PROJECT_SUMMARY               	Experiment to test the consequence of a mutation at the FatB gene (At1g08510)
#    PR:PROJECT_SUMMARY               	the wound-response of Arabidopsis
#
# .. note::
#
#    ``*_SUMMARY`` "key-value"-like pairs are typically span through multiple lines.
#
#
# * ``#SUBJECT_SAMPLE_FACTORS`` block is specially formatted, i.e. it contains header
#   specification and tab-separated values.
#
# .. code-block:: none
#
#    #SUBJECT_SAMPLE_FACTORS:         	SUBJECT(optional)[tab]SAMPLE[tab]FACTORS(NAME:VALUE pairs separated by |)[tab]Additional sample data
#    SUBJECT_SAMPLE_FACTORS           	-	LabF_115873	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded
#    SUBJECT_SAMPLE_FACTORS           	-	LabF_115878	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded
#    SUBJECT_SAMPLE_FACTORS           	-	LabF_115883	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded
#    SUBJECT_SAMPLE_FACTORS           	-	LabF_115888	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded
#    SUBJECT_SAMPLE_FACTORS           	-	LabF_115893	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded
#    SUBJECT_SAMPLE_FACTORS           	-	LabF_115898	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded
#
#
# * ``#MS_METABOLITE_DATA`` (results) block contains ``Samples`` identifiers, ``Factors`` identifiers
#   as well as tab-separated data between ``*_START`` and ``*_END``.
#
# .. code-block:: none
#
#    #MS_METABOLITE_DATA
#    MS_METABOLITE_DATA:UNITS	Peak height
#    MS_METABOLITE_DATA_START
#    Samples	LabF_115904	LabF_115909	LabF_115914	LabF_115919	LabF_115924	LabF_115929	LabF_115842	LabF_115847	LabF_115852	LabF_115857	LabF_115862	LabF_115867	LabF_115873	LabF_115878	LabF_115883	LabF_115888	LabF_115893	LabF_115898	LabF_115811	LabF_115816	LabF_115821	LabF_115826	LabF_115831	LabF_115836
#    Factors	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:fatb-ko KD; At1g08510 | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Control - Non-Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Wounded	Arabidopsis Genotype:Wassilewskija (Ws) | Plant Wounding Treatment:Wounded
#    1_2_4-benzenetriol	1874.0000	3566.0000	1945.0000	1456.0000	2004.0000	1995.0000	4040.0000	2432.0000	2189.0000	1931.0000	1307.0000	2880.0000	2218.0000	1754.0000	1369.0000	1201.0000	3324.0000	1355.0000	2257.0000	1718.0000	1740.0000	3472.0000	2054.0000	1367.0000
#    1-monostearin	987.0000	450.0000	1910.0000	549.0000	1032.0000	902.0000	393.0000	705.0000	100.0000	481.0000	265.0000	120.0000	1185.0000	867.0000	676.0000	569.0000	579.0000	387.0000	1035.0000	789.0000	875.0000	224.0000	641.0000	693.0000
#    ...
#    MS_METABOLITE_DATA_END
#
# * ``#METABOLITES`` metadata block contains a header specifying fields and
#   tab-separated data between ``*_START`` and ``*_END``.
#
# .. code-block:: none
#
#    #METABOLITES
#    METABOLITES_START
#    metabolite_name	moverz_quant	ri	ri_type	pubchem_id	inchi_key	kegg_id	other_id	other_id_type
#    1,2,4-benzenetriol	239	522741	Fiehn	10787		C02814	205673	BinBase
#    1-monostearin	399	959625	Fiehn	107036		D01947	202835	BinBase
#    2-hydroxyvaleric acid	131	310750	Fiehn	98009			218773	BinBase
#    3-phosphoglycerate	299	611619	Fiehn	724		C00597	217821	BinBase
#    ...
#    METABOLITES_END
#
# * ``#NMR_BINNED_DATA`` metadata block contains a header specifying fields and
#   tab-separated data between ``*_START`` and ``*_END``.
#
# .. code-block:: none
#
#    #NMR_BINNED_DATA
#    NMR_BINNED_DATA_START
#    Bin range(ppm)	CDC029	CDC030	CDC032	CPL101	CPL102	CPL103	CPL201	CPL202	CPL203	CDS039	CDS052	CDS054
#    0.50...0.56	0.00058149	1.6592	0.039301	0	0	0	0.034018	0.0028746	0.0021478	0.013387	0	0
#    0.56...0.58	0	0.74267	0	0.007206	0	0	0	0	0	0	0	0.0069721
#    0.58...0.60	0.051165	0.8258	0.089149	0.060972	0.026307	0.045697	0.069541	0	0	0.14516	0.057489	0.042255
#    ...
#    NMR_BINNED_DATA_END
#
# * Order of metadata and data blocks (MS)
#
# .. code-block:: none
#
#    #METABOLOMICS WORKBENCH
#    VERSION             	1
#    CREATED_ON          	2016-09-17
#    ...
#    #PROJECT
#    ...
#    #STUDY
#    ...
#    #SUBJECT
#    ...
#    #SUBJECT_SAMPLE_FACTORS:         	SUBJECT(optional)[tab]SAMPLE[tab]FACTORS(NAME:VALUE pairs separated by |)[tab]Additional sample data
#    ...
#    #COLLECTION
#    ...
#    #TREATMENT
#    ...
#    #SAMPLEPREP
#    ...
#    #CHROMATOGRAPHY
#    ...
#    #ANALYSIS
#    ...
#    #MS
#    ...
#    #MS_METABOLITE_DATA
#    MS_METABOLITE_DATA:UNITS	peak area
#    MS_METABOLITE_DATA_START
#    ...
#    MS_METABOLITE_DATA_END
#    #METABOLITES
#    METABOLITES_START
#    ...
#    METABOLITES_END
#    #END

# %% [raw]
# Using mwtab as a Library
# ~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# Importing mwtab Package
# -----------------------
#
# If the :mod:`mwtab` package is installed on the system, it can be imported:

# %%
import mwtab

# %% [raw]
# Constructing MWTabFile Generator
# --------------------------------
#
# The :mod:`~mwtab.fileio` module provides the :func:`~mwtab.fileio.read_files`
# generator function that yields :class:`~mwtab.mwtab.MWTabFile` instances. Constructing a
# :class:`~mwtab.mwtab.MWTabFile` generator is easy - specify the path to a local ``mwTab`` file,
# directory of files, archive of files:

# %%
import mwtab

mwfile_gen = mwtab.read_files("ST000017_AN000035.txt")  # single mwTab file
mwfiles_gen = mwtab.read_files("ST000017_AN000035.txt", "ST000040_AN000060.json")  # several mwTab files
mwdir_gen = mwtab.read_files("mwfiles_dir_mwtab")  # directory of mwTab files
mwzip_gen = mwtab.read_files("mwfiles_mwtab.zip")  # archive of mwTab files
mwanalysis_gen = mwtab.read_files("35", "60")       # ANALYSIS_ID of mwTab file
# REST callable url of mwTab file
mwurl_gen = mwtab.read_files("https://www.metabolomicsworkbench.org/rest/study/analysis_id/AN000035/mwtab/txt")

# %% [raw]
# Processing MWTabFile Generator
# ------------------------------
#
# The :class:`~mwtab.mwtab.MWTabFile` generator can be processed in several ways:
#
# * Feed it to a for-loop and process one file at a time:

# %%
for mwfile in mwtab.read_files("35", "60"):
    print("STUDY_ID:", mwfile.study_id)       # print STUDY_ID
    print("ANALYSIS_ID", mwfile.analysis_id)  # print ANALYSIS_ID
    print("SOURCE", mwfile.source)            # print source
    for block_name in mwfile:                 # print names of blocks
        print("\t", block_name)
# Out:
# STUDY_ID: ST000017
# ANALYSIS_ID AN000035
# SOURCE https://www.metabolomicsworkbench.org/rest/study/analysis_id/AN000035/mwtab/txt
# 	 METABOLOMICS WORKBENCH
# 	 PROJECT
# 	 STUDY
# 	 SUBJECT
# 	 SUBJECT_SAMPLE_FACTORS
# 	 COLLECTION
# 	 TREATMENT
# 	 SAMPLEPREP
# 	 CHROMATOGRAPHY
# 	 ANALYSIS
# 	 MS
# 	 MS_METABOLITE_DATA
# STUDY_ID: ST000040
# ANALYSIS_ID AN000060
# SOURCE https://www.metabolomicsworkbench.org/rest/study/analysis_id/AN000060/mwtab/txt
# 	 METABOLOMICS WORKBENCH
# 	 PROJECT
# 	 STUDY
# 	 SUBJECT
# 	 SUBJECT_SAMPLE_FACTORS
# 	 COLLECTION
# 	 TREATMENT
# 	 SAMPLEPREP
# 	 CHROMATOGRAPHY
# 	 ANALYSIS
# 	 MS
# 	 MS_METABOLITE_DATA

# %% [raw]
# .. note:: Once the generator is consumed, it becomes empty and needs to be created again.

# %% [raw]
# * Since the :class:`~mwtab.mwtab.MWTabFile` generator behaves like an iterator,
#   we can call the :py:func:`next` built-in function:

# %%
mwfiles_generator = mwtab.read_files("35", "60")

mwfile1 = next(mwfiles_generator)
mwfile2 = next(mwfiles_generator)

# %% [raw]
# .. note:: Once the generator is consumed, :py:class:`StopIteration` will be raised.

# %% [raw]
# * Convert the :class:`~mwtab.mwtab.MWTabFile` generator into a :py:class:`list` of
#   :class:`~mwtab.mwtab.MWTabFile` objects:

# %%
mwfiles_generator = mwtab.read_files("35", "60")
mwfiles_list = list(mwfiles_generator)

# %% [raw]
# .. warning:: Do not convert the :class:`~mwtab.mwtab.MWTabFile` generator into a
#              :py:class:`list` if the generator can yield a large number of files, e.g.
#              several thousand, otherwise it can consume all available memory.

# %% [raw]
# Accessing Data From a Single MWTabFile
# --------------------------------------
#
# Since a :class:`~mwtab.mwtab.MWTabFile` is a Python :py:class:`collections.OrderedDict`,
# data can be accessed and manipulated as with any regular Python :py:class:`dict` object
# using bracket accessors.
#
# * Accessing top-level "keys" in :class:`~mwtab.mwtab.MWTabFile`:

# %%
import os
os.chdir('_static/mwfiles')

# %%
mwfile = next(mwtab.read_files("ST000017_AN000035.txt"))

# list MWTabFile-level keys, i.e. saveframe names
list(mwfile.keys())
# Out:
# ['METABOLOMICS WORKBENCH',
#  'PROJECT',
#  'STUDY',
#  'SUBJECT',
#  'SUBJECT_SAMPLE_FACTORS',
#  'COLLECTION',
#  'TREATMENT',
#  'SAMPLEPREP',
#  'CHROMATOGRAPHY',
#  'ANALYSIS',
#  'MS',
#  'MS_METABOLITE_DATA']

# %% [raw]
# * Accessing individual blocks in :class:`~mwtab.mwtab.MWTabFile`:

# %%
# access "PROJECT" block
mwfile["PROJECT"]
# Out:
# OrderedDict([('PROJECT_TITLE', 'Rat Stamina Studies'),
#              ('PROJECT_TYPE', 'Feeding'),
#              ('PROJECT_SUMMARY', 'Stamina in rats'),
#              ('INSTITUTE', 'University of Michigan'),
#              ('DEPARTMENT', 'Internal Medicine'),
#              ('LABORATORY', 'Burant Lab'),
#              ('LAST_NAME', 'Beecher'),
#              ('FIRST_NAME', 'Chris'),
#              ('ADDRESS', '-'),
#              ('EMAIL', 'chrisbee@med.umich.edu'),
#              ('PHONE', '734-232-0815'),
#              ('FUNDING_SOURCE', 'NIH: R01 DK077200')])

# %% [raw]
# * Accessing individual "key-value" pairs within blocks:

# %%
# access "INSTITUTE" field within "PROJECT" block
mwfile["PROJECT"]["INSTITUTE"]
# Out:
# 'University of Michigan'

# %% [raw]
# * Accessing data in ``#SUBJECT_SAMPLE_FACTORS`` block:

# %%
# access "SUBJECT_SAMPLE_FACTORS" block
mwfile["SUBJECT_SAMPLE_FACTORS"]
# Out:
# [OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009477'),
#               ('Factors',
#                {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009478'),
#               ('Factors',
#                {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009479'),
#               ('Factors',
#                {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009480'),
#               ('Factors',
#                {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009481'),
#               ('Factors',
#                {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009500'),
#               ('Factors',
#                {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009501'),
#               ('Factors',
#                {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009502'),
#               ('Factors',
#                {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009503'),
#               ('Factors',
#                {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009470'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009471'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009472'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009473'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009474'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009475'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009494'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009495'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009496'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009497'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009498'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009499'),
#               ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009488'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009489'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009490'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009491'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009492'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009493'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009509'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009510'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009511'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009512'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009513'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009514'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'High'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009482'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009483'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009484'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009486'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009504'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009505'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009506'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009507'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'Low'})]),
#  OrderedDict([('Subject ID', '-'),
#               ('Sample ID', 'S00009508'),
#               ('Factors',
#                {'Feeeding': 'Calorie restricted',
#                 'Running Capacity': 'Low'})])]

# %%
# access individual factors (by index)
mwfile["SUBJECT_SAMPLE_FACTORS"][0]
# Out:
# OrderedDict([('Subject ID', '-'),
#              ('Sample ID', 'S00009477'),
#              ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})])

# %%
# access individual fields within factors
mwfile["SUBJECT_SAMPLE_FACTORS"][0]["Sample ID"]
# Out:
# 'S00009477'

# %% [raw]
# * Accessing data in ``#MS_METABOLITE_DATA`` block:

# %%
# access entire block
mwfile["MS_METABOLITE_DATA"]
# Out:
# OrderedDict([('Units', 'peak area'),
#              ('Data',
#               [OrderedDict([('Metabolite',
#                              '11BETA_21-DIHYDROXY-5BETA-PREGNANE-3_20-DIONE'),
#                             ('S00009477', ''),
#                             ('S00009478', ''),
#                             ('S00009479', ''),
#                             ('S00009480', ''),
#                             ('S00009481', ''),
#                             ('S00009500', ''),
#                             ('S00009501', ''),
#                             ('S00009502', ''),
#                             ('S00009503', ''),
#                             ('S00009470', ''),
#                             ('S00009471', ''),
#                             ('S00009472', ''),
#                             ('S00009473', ''),
#                             ('S00009474', '476477.0000'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'DIHOMO-LINOLENATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'DOCOSAPENTAENOATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'DODECANEDIOATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'DODECENOATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'DOPAMINE 3-O-SULFATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'FORMYLANTHRANILATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'GAMA-L-GLUTAMYL-L-ALANINE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite',
#                              'GLYCODEOXYCHOLATE / GLYCOCHENODEOXYCHOLATE  (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'HEXADECANEDIOATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'HYDROXYACETAMINOPHEN SULFATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'HYDROXYDECANOATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'HYDROXYISOVALERATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'INDOLEPROPIONATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'ISOLEUCINE/LEUCINE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'LACTOYLGLUTATHIONE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite',
#                              'LINOLEOYLGLYCEROPHOSPHOETHANOLAMINE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'N(PAI)-METHYL-L-HISTIDINE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'OCTADECANEDIOATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite',
#                              'OLEOYLGLYCEROPHOSPHOETHANOLAMINE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'OXALOSUCCINATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'P-ACETAMIDOPHENYLGLUCURONIDE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite',
#                              'PALMITOYLGLYCEROPHOSPHOETHANOLAMINE  / PALMITOYLPLASMENYLETHANOLAMINE  (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite',
#                              'PALMITOYLGLYCEROPHOSPHOINOSITOL (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'PHENYLACETATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'PREGN STEROID MONOSULFATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'PROSTAGLANDIN E1 (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'PROSTAGLANDIN G2 (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'SALICYLURIC GLUCURONIDE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'SPHINGOSINE 1-PHOSPHATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'STEARIDONATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite',
#                              'STEAROYLGLYCEROPHOSPHOETHANOLAMINE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite',
#                              'STEAROYLGLYCEROPHOSPHOETHANOLAMINE (*)_2'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'TAUROCHENODEOXYCHOLATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'TAUROCHOLATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'THREONATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'TRYPTOPHAN (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'UROCORTISONE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'XANTHOSINE 5`-MONOPHOSPHATE'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')]),
#                OrderedDict([('Metabolite', 'XYLONATE (*)'),
#                             ('moverz_quant', ''),
#                             ('ri', ''),
#                             ('ri_type', ''),
#                             ('pubchem_id', ''),
#                             ('inchi_key', ''),
#                             ('kegg_id', ''),
#                             ('other_id', '')])])])

# %%
# access units field
mwfile["MS_METABOLITE_DATA"]["Units"]
# Out:
# 'peak area'

# %%
# access samples field
mwfile["MS_METABOLITE_DATA"]["Data"][0].keys()
# Out:
# odict_keys(['Metabolite', 'S00009477', 'S00009478', 'S00009479', 'S00009480', 'S00009481', 'S00009500', 'S00009501', 'S00009502', 'S00009503', 'S00009470', 'S00009471', 'S00009472', 'S00009473', 'S00009474', 'S00009475', 'S00009494', 'S00009495', 'S00009496', 'S00009497', 'S00009498', 'S00009499', 'S00009488', 'S00009489', 'S00009490', 'S00009491', 'S00009492', 'S00009493', 'S00009509', 'S00009510', 'S00009511', 'S00009512', 'S00009513', 'S00009514', 'S00009482', 'S00009483', 'S00009484', 'S00009486', 'S00009504', 'S00009505', 'S00009506', 'S00009507', 'S00009508'])

# %%
# access metabolite data
mwfile["MS_METABOLITE_DATA"]["Metabolites"]
# Out:
# [OrderedDict([('Metabolite', '11BETA,21-DIHYDROXY-5BETA-PREGNANE-3,20-DIONE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '44263339'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C05475'),
#               ('other_id', '775216_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', '11-BETA-HYDROXYANDROST-4-ENE-3,17-DIONE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '94141'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C05284'),
#               ('other_id', '771312_PRIMARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', '13(S)-HPODE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '1426'),
#               ('inchi_key', ''),
#               ('kegg_id', '
UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'B-ALANYL-N(PAI)-METHYL-L-HISTIDINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '112072'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C01262'),
#               ('other_id', '771080_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BEHENIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '8215'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C08281'),
#               ('other_id', '771104_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BENZOATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '243'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00180'),
#               ('other_id', '770974_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BILIVERDIN'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5280353'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00500'),
#               ('other_id', '771079_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BOC-A-(1-NAPHTHYLMETHYL)-DL-PRO-OH'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '771043_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BOC-ASN'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '82035'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C01410'),
#               ('other_id', '771273_PRIMARY_NOT_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BOC-ASP-OH'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '302432'),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '775185_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BOC-MET-OH'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '111051'),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '771122_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BOC-PHE-OH'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '77857'),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '771306_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BOC-PRO-OH'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '85083'),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '771431_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'BOC-THR-OH'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '45357648'),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '771440_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', '[C13] METHIONINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '876'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C01733'),
#               ('other_id', '771199_PRIMARY_NOT_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', '[C13] PHENYLALANINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '994'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C02057'),
#               ('other_id', '771201_PRIMARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', '[C13] TYROSINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '1153'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C01536'),
#               ('other_id', '771200_PRIMARY_NOT_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', '[C13] VALINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '247'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00719'),
#               ('other_id', '771176_PRIMARY_NOT_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CAPRYLIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '379'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C06423'),
#               ('other_id', '771091_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CARNOSINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '439224'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00386'),
#               ('other_id', '771221_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CATECHOL'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '289'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00090'),
#               ('other_id', '771129_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CHENODEOXYCHOLATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '10133'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C02528'),
#               ('other_id', '771089_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CHOLATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '221493'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00695'),
#               ('other_id', '770971_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CHOLESTEROL'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5997'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00187'),
#               ('other_id', '778148_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CHOLESTEROL SULFATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '65076'),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '780248_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CINNAMIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5372954'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C10438'),
#               ('other_id', '771036_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CIS-7,10,13,16-DOCOSATETRAENOIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5497181'),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '771151_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CITRATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '311'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00158'),
#               ('other_id', '771156_PRIMARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CITRULLINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '9750'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00327'),
#               ('other_id', '774891_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CORTICOSTERONE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5753'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C02140'),
#               ('other_id', '771309_PRIMARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CYCLOHEPTANECARBOXYLIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '15091'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C12104'),
#               ('other_id', '771268_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CYS-GLY'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '439498'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C01419'),
#               ('other_id', '771276_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'CYSTATHIONINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '10104953'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00542'),
#               ('other_id', '771290_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DECANOATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '2969'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C01571'),
#               ('other_id', '771040_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DEHYDROISOANDROSTERONE 3-SULFATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '12594'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C04555'),
#               ('other_id', '771315_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DEOXYCORTICOSTERONE ACETATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5952'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C14554'),
#               ('other_id', '771098_PRIMARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DESMETHYLNAPROXEN SULFATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '777122_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DIETHYL 2-METHYL-3-OXOSUCCINATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '97750'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C04067'),
#               ('other_id', '771320_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DIHEXOSE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '771456_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DIHOMO-LINOLEATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '6439848'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C16525'),
#               ('other_id', '773539_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DIHOMO-LINOLENATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5280581'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C03242'),
#               ('other_id', '774630_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DIHYDROXYACETONE PHOSPHATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '668'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00111'),
#               ('other_id', '770997_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DIMETHYLXANTHINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '185974'),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '777148_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DOCOSAHEXAENOIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '445580'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C06429'),
#               ('other_id', '771266_PRIMARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DOCOSAPENTAENOATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5497182'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C16513'),
#               ('other_id', '777922_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DODECANEDIOATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '12736'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C02678'),
#               ('other_id', '777951_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DODECENOATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '774990_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'DOPAMINE 3-O-SULFATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '122136'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C13690'),
#               ('other_id', '776196_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'ERUCIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5281116'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C08316'),
#               ('other_id', '771149_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'ESTRADIOL-17BETA'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5757'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00951'),
#               ('other_id', '771332_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'FORMYLANTHRANILATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '101399'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C05653'),
#               ('other_id', '775206_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'FORMYL-L-METHIONINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '6995182'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C03145'),
#               ('other_id', '771365_PRIMARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'FRUCTOSE 1,6-BIPHOSPHATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '172313'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00354'),
#               ('other_id', '771220_PRIMARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'FUMARIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '444972'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00122'),
#               ('other_id', '771185_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GAMA-L-GLUTAMYL-L-ALANINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '778042_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GAMMA-LINOLENIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '5280933'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C06426'),
#               ('other_id', '770984_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GERANYL PYROPHOSPHATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '447277'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00353'),
#               ('other_id', '771063_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GLUCURONOLACTONE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '439782'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C02670'),
#               ('other_id', '771302_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GLUTAMIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '611'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00302'),
#               ('other_id', '771454_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GLUTAMINE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '738'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00303'),
#               ('other_id', '771400_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GLYCERIC ACID'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '439194'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C00258'),
#               ('other_id', '771001_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GLYCEROL PHOSPHATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '771464_UNIQUE'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GLYCOCHOLATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', '10140'),
#               ('inchi_key', ''),
#               ('kegg_id', 'C01921'),
#               ('other_id', '771126_SECONDARY'),
#               ('other_id_type', 'UM_Target_ID')]),
#  OrderedDict([('Metabolite', 'GLYCODEOXYCHOLATE / GLYCOCHENODEOXYCHOLATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
# ...
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite',
#                '3ALPHA,7ALPHA,12ALPHA-TRIHYDROXY-5BETA-CHOLESTANOATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', '3ALPHA,7ALPHA-DIHYDROXY-5BETA-CHOLESTANATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite',
#                '4-(2-AMINO-3-HYDROXYPHENYL)-2,4-DIOXOBUTANOATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', '4-ANDROSTEN-3BETA,17BETA-DIOL DISULFATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', '4-OXOGLUTARAMATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', '4-VINYLPHENOL SULFATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', '7-ALPHA-HYDROXY-3-OXO-4-CHOLESTENOATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', '9(10)-EPOME (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'ACONITATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'ALPHA-TOCOPHEROL (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'ANDROSTERONE GLUCURONIDE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'ARACHIDONOYLGLYCEROPHOSPHOETHANOLAMINE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'ARACHIDONOYLGLYCEROPHOSPHOINOSITOL (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'CHOLESTEROL (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'DESMETHYLNAPROXEN SULFATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'DIHOMO-LINOLEATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'DIHOMO-LINOLENATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'DOCOSAPENTAENOATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'DODECANEDIOATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'DODECENOATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'DOPAMINE 3-O-SULFATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'FORMYLANTHRANILATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'GAMA-L-GLUTAMYL-L-ALANINE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite',
#                'GLYCODEOXYCHOLATE / GLYCOCHENODEOXYCHOLATE  (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'HEXADECANEDIOATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'HYDROXYACETAMINOPHEN SULFATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'HYDROXYDECANOATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'HYDROXYISOVALERATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'INDOLEPROPIONATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'ISOLEUCINE/LEUCINE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'LACTOYLGLUTATHIONE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'LINOLEOYLGLYCEROPHOSPHOETHANOLAMINE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'N(PAI)-METHYL-L-HISTIDINE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'OCTADECANEDIOATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'OLEOYLGLYCEROPHOSPHOETHANOLAMINE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'OXALOSUCCINATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'P-ACETAMIDOPHENYLGLUCURONIDE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite',
#                'PALMITOYLGLYCEROPHOSPHOETHANOLAMINE  / PALMITOYLPLASMENYLETHANOLAMINE  (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'PALMITOYLGLYCEROPHOSPHOINOSITOL (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'PHENYLACETATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'PREGN STEROID MONOSULFATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'PROSTAGLANDIN E1 (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'PROSTAGLANDIN G2 (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'SALICYLURIC GLUCURONIDE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'SPHINGOSINE 1-PHOSPHATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'STEARIDONATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'STEAROYLGLYCEROPHOSPHOETHANOLAMINE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'STEAROYLGLYCEROPHOSPHOETHANOLAMINE (*)_2'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'TAUROCHENODEOXYCHOLATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'TAUROCHOLATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'THREONATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'TRYPTOPHAN (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'UROCORTISONE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'XANTHOSINE 5`-MONOPHOSPHATE'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')]),
#  OrderedDict([('Metabolite', 'XYLONATE (*)'),
#               ('moverz_quant', ''),
#               ('ri', ''),
#               ('ri_type', ''),
#               ('pubchem_id', ''),
#               ('inchi_key', ''),
#               ('kegg_id', ''),
#               ('other_id', '')])]

# %% [raw]
# Manipulating Data From a Single MWTabFile
# -----------------------------------------
#
# In order to change values within :class:`~mwtab.mwtab.MWTabFile`, descend into
# the appropriate level using square bracket accessors and set a new value.
#
# * Change regular "key-value" pairs:

# %%
# access phone number information
mwfile["PROJECT"]["PHONE"]
# Out:
# '734-232-0815'

# %%
# change phone number information
mwfile["PROJECT"]["PHONE"] = "1-530-754-8258"

# %%
# check that it has been modified
mwfile["PROJECT"]["PHONE"]
# Out:
# '1-530-754-8258'

# %% [raw]
# * Change ``#SUBJECT_SAMPLE_FACTORS`` values:

# %%
# access the first subject sample factor by index
mwfile["SUBJECT_SAMPLE_FACTORS"][0]
# Out:
# OrderedDict([('Subject ID', '-'),
#              ('Sample ID', 'S00009477'),
#              ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'High'})])

# %%
# provide additional details to the first subject sample factor
mwfile["SUBJECT_SAMPLE_FACTORS"][0]["Additional sample data"] = {"Additional detail key": "Additional detail value"}

# %%
# check that it has been modified
mwfile["SUBJECT_SAMPLE_FACTORS"][0]
# Out:
# OrderedDict([('Subject ID', '-'),
#              ('Sample ID', 'S00009477'),
#              ('Factors', {'Feeeding': 'Ad lib', 'Running Capacity': 'High'}),
#              ('Additional sample data',
#               {'Additional detail key': 'Additional detail value'})])

# %% [raw]
# Printing a MWTabFile and its Components
# ---------------------------------------
#
# * Print entire file in ``mwTab`` format.

# %%
mwfile.print_file(file_format="mwtab")
# Out:
# #METABOLOMICS WORKBENCH STUDY_ID:ST000017 ANALYSIS_ID:AN000035 PROJECT_ID:PR000016
# VERSION             	1
# CREATED_ON          	2016-09-17
# #PROJECT
# PR:PROJECT_TITLE                 	Rat Stamina Studies
# PR:PROJECT_TYPE                  	Feeding
# PR:PROJECT_SUMMARY               	Stamina in rats
# PR:INSTITUTE                     	University of Michigan
# PR:DEPARTMENT                    	Internal Medicine
# PR:LABORATORY                    	Burant Lab
# PR:LAST_NAME                     	Beecher
# PR:FIRST_NAME                    	Chris
# PR:ADDRESS                       	-
# PR:EMAIL                         	chrisbee@med.umich.edu
# PR:PHONE                         	1-530-754-8258
# PR:FUNDING_SOURCE                	NIH: R01 DK077200
# #STUDY
# ST:STUDY_TITLE                   	Rat HCR/LCR Stamina Study
# ST:STUDY_TYPE                    	LC-MS analysis
# ST:STUDY_SUMMARY                 	To determine the basis of running capacity and health differences in outbread
# ST:STUDY_SUMMARY                 	N/NIH rats selected for high capacity (HCR) and low capacity (LCR) running (a for
# ST:STUDY_SUMMARY                 	VO2max) (see:Science. 2005 Jan 21;307(5708):418-20). Plasma collected at 12 of
# ST:STUDY_SUMMARY                 	age in generation 28 rats after ad lib feeding or 40% caloric restriction at week
# ST:STUDY_SUMMARY                 	8 of age. All animals fasted 4 hours prior to collection between 5-8
# ST:INSTITUTE                     	University of Michigan
# ST:DEPARTMENT                    	Internal Medicine
# ST:LABORATORY                    	Burant Lab (MMOC)
# ST:LAST_NAME                     	Qi
# ST:FIRST_NAME                    	Nathan
# ST:ADDRESS                       	-
# ST:EMAIL                         	nathanqi@med.umich.edu
# ST:PHONE                         	734-232-0815
# ST:NUM_GROUPS                    	2
# ST:TOTAL_SUBJECTS                	42
# #SUBJECT
# SU:SUBJECT_TYPE                  	Animal
# SU:SUBJECT_SPECIES               	Rattus norvegicus
# SU:TAXONOMY_ID                   	10116
# SU:GENOTYPE_STRAIN               	Low Capacity Running | High Capacity Running
# SU:SPECIES_GROUP                 	Mammal
# #SUBJECT_SAMPLE_FACTORS:         	SUBJECT(optional)[tab]SAMPLE[tab]FACTORS(NAME:VALUE pairs separated by |)[tab]Additional sample data
# SUBJECT_SAMPLE_FACTORS                                 	-	S00009477	Feeeding:Ad lib | Running Capacity:High	Additional detail key=Additional detail value
# #COLLECTION
# CO:COLLECTION_SUMMARY            	-
# CO:SAMPLE_TYPE                   	Serum
# CO:VOLUMEORAMOUNT_COLLECTED      	50 ul
# #TREATMENT
# TR:TREATMENT_SUMMARY             	ad lib feeding | Calorie restricted feeding
# #SAMPLEPREP
# SP:SAMPLEPREP_SUMMARY            	-
# SP:SAMPLEPREP_PROTOCOL_FILENAME  	EX00166-Sample_preparation_protocol.pdf
# #CHROMATOGRAPHY
# CH:CHROMATOGRAPHY_SUMMARY        	Negative ion detection
# CH:CHROMATOGRAPHY_TYPE           	Reversed phase
# CH:INSTRUMENT_NAME               	Agilent 1200
# CH:COLUMN_NAME                   	Waters Acquity HSS T3 reversed-phase
# CH:METHODS_FILENAME              	EX00166-LCMS-method.pdf
# CH:COLUMN_TEMPERATURE            	40C
# CH:FLOW_GRADIENT                 	0-0.5 min 1% B, 0.5-2 min 1-99% B, 2-6 min 99% B, 6-9 min 1% B.
# CH:FLOW_RATE                     	0.35 mL/min
# CH:SOLVENT_A                     	100% water with 0.1% ammonium bicarbonate
# CH:SOLVENT_B                     	100% methanol with 0.1% ammonium bicarbonate
# #ANALYSIS
# AN:ANALYSIS_TYPE                 	MS
# AN:ACQUISITION_PARAMETERS_FILE   	EX00166-LCMS-method.pdf
# AN:PROCESSING_PARAMETERS_FILE    	EX00166-Data_analysis-method.pdf
# AN:DETECTOR_TYPE                 	LC / Electro-spray /QTOF MS Negative
# #MS
# MS:INSTRUMENT_NAME               	Agilent 6530 QTOF
# MS:INSTRUMENT_TYPE               	QTOF
# MS:MS_TYPE                       	ESI
# MS:ION_MODE                      	NEGATIVE
# MS:MS_COMMENTS                   	Reference masses 62.0009 and 981.9956 m/z.
# MS:CAPILLARY_VOLTAGE             	3500V
# MS:ION_SOURCE_TEMPERATURE        	350 C
# #MS_METABOLITE_DATA
# MS_METABOLITE_DATA:UNITS         	peak area
# MS_METABOLITE_DATA_START
# Samples	S00009477	S00009478	S00009479	S00009480	S00009481	S00009500	S00009501	S00009502	S00009503	S00009470	S00009471	S00009472	S00009473	S00009474	S00009475	S00009494	S00009495	S00009496	S00009497	S00009498	S00009499	S00009488	S00009489	S00009490	S00009491	S00009492	S00009493	S00009509	S00009510	S00009511	S00009512	S00009513	S00009514	S00009482	S00009483	S00009484	S00009486	S00009504	S00009505	S00009506	S00009507	S00009508
# Factors	Feeeding:Ad lib | Running Capacity:High	Feeeding:Ad lib | Running Capacity:High	Feeeding:Ad lib | Running Capacity:High	Feeeding:Ad lib | Running Capacity:High	Feeeding:Ad lib | Running Capacity:High	Feeeding:Ad lib | Running Capacity:High	Feeeding:Ad lib | Running Capacity:High	Feeeding:Ad lib | Running Capacity:High	Feeeding:Ad lib | Running Capacity:High	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Ad lib | Running Capacity:Low	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:High	Feeeding:Calorie restricted | Running Capacity:Low	Feeeding:Calorie restricted | Running Capacity:Low	Feeeding:Calorie restricted | Running Capacity:Low	Feeeding:Calorie restricted | Running Capacity:Low	Feeeding:Calorie restricted | Running Capacity:Low	Feeeding:Calorie restricted | Running Capacity:Low	Feeeding:Calorie restricted | Running Capacity:Low	Feeeding:Calorie restricted | Running Capacity:Low	Feeeding:Calorie restricted | Running Capacity:Low
# 11BETA_21-DIHYDROXY-5BETA-PREGNANE-3_20-DIONE														476477.0000										1654198.0000
# 3-HYDROXYBENZYL ALCOHOL				102		C03351	770896_UNIQUE	UM_Target_ID
# 3-HYDROXY-DL-KYNURENINE				89		C02794	771337_SECONDARY	UM_Target_ID
# 3-METHOXY-L-TYROSINE				9307			771360_SECONDARY	UM_Target_ID
# 3-METHYL-2-OXINDOLE				150923			770954_SECONDARY	UM_Target_ID
# 3-METHYL-2-OXOBUTANOIC ACID				49		C00141	780285_UNIQUE	UM_Target_ID
# 3-METHYL-2-OXOVALERIC ACID				47		C03465	771203_UNIQUE	UM_Target_ID
# 3-METHYLADENINE				1673		C00913	770955_UNIQUE	UM_Target_ID
# 3-NITRO-L-TYROSINE				235719			771505_UNIQUE	UM_Target_ID
# 3-SULFINO-L-ALANINE				439270		C00606	771272_UNIQUE	UM_Target_ID
# 4-(2-AMINO-3-HYDROXYPHENYL)-2,4-DIOXOBUTANOATE				440741		C05645	774751_UNIQUE	UM_Target_ID
# 4-ACETAMIDOBUTANOATE				18189		C02946	771288_SECONDARY	UM_Target_ID
# 4-AMINOBENZOATE				978		C00568	771019_SECONDARY	UM_Target_ID
# 4-ANDROSTEN-3BETA,17BETA-DIOL DISULFATE				10634		C04295	778021_UNIQUE	UM_Target_ID
# 4-HYDROXY-2-QUINOLINECARBOXYLIC ACID				3845		C01717	770895_PRIMARY_NOT_UNIQUE	UM_Target_ID
# 4-HYDROXY-3-METHOXY-BENZENEMETHANOL				62348		C06317	770920_UNIQUE	UM_Target_ID
# 4-HYDROXY-3-METHOXYPHENYLGLYCOL				10805			771246_SECONDARY	UM_Target_ID
# 4-HYDROXYBENZALDEHYDE				126		C00633	771186_UNIQUE	UM_Target_ID
# 4-HYDROXYPHENYLACETATE				127		C00642	771225_UNIQUE	UM_Target_ID
# 4-OXOGLUTARAMATE				440726		C05572	775325_UNIQUE	UM_Target_ID
# 4-PYRIDOXATE				6723		C00847	771274_SECONDARY	UM_Target_ID
# 4-VINYLPHENOL SULFATE				62453		C05627	776310_UNIQUE	UM_Target_ID
# 5,6-DIHYDROURACIL				649		C00429	770887_UNIQUE	UM_Target_ID
# 5-AMINOLEVULINIC ACID				137		C00430	771046_UNIQUE	UM_Target_ID
# 5-HYDROXYINDOLE-3-ACETIC ACID				1826		C05635	780627_UNIQUE	UM_Target_ID
# 5-HYDROXY-L-TRYPTOPHAN				439280		C00643	771389_UNIQUE	UM_Target_ID
# 5-OXO-PROLINE				7405		C01879	771283_PRIMARY	UM_Target_ID
# 5-PHOSPHO-ALPHA-D-RIBOSE				7339		C00119	771240_UNIQUE	UM_Target_ID
# 6-HYDROXYNICOTINATE				72924		C01020	771354_UNIQUE	UM_Target_ID
# 6-PHOSPHOGLUCONIC ACID				91493		C00345	771172_UNIQUE	UM_Target_ID
# 7-ALPHA-HYDROXY-3-OXO-4-CHOLESTENOATE				53481411		C17337	773862_UNIQUE	UM_Target_ID
# 9(10)-EPOME				5316080		C14825	777865_UNIQUE	UM_Target_ID
# ACETYLENEDICARBOXYLATE				371		C03248	770935_UNIQUE	UM_Target_ID
# ACONITATE				643757		C00417	773244_UNIQUE	UM_Target_ID
# ADENINE				190		C00147	771341_UNIQUE	UM_Target_ID
# ALDOSTERONE				5839		C01780	770869_UNIQUE	UM_Target_ID
# ALPHA-TOCOPHEROL				14985		C02477	773439_SECONDARY	UM_Target_ID
# AMINOBUTANOIC ACID				119			771460_UNIQUE	UM_Target_ID
# AMINOHYDROXYBUTANOIC ACID							771453_PRIMARY	UM_Target_ID
# AMINOPENTANOIC ACID							771406_UNIQUE	UM_Target_ID
# ANANDAMIDE				5281969		C11695	770986_UNIQUE	UM_Target_ID
# ANDROSTERONE GLUCURONIDE				114833		C11135	775833_UNIQUE	UM_Target_ID
# ANILINE-2-SULFONIC ACID				6926			771379_UNIQUE	UM_Target_ID
# ARACHIDIC ACID				10467		C06425	771112_UNIQUE	UM_Target_ID
# ARACHIDONATE				444899		C00219	771238_UNIQUE	UM_Target_ID
# ARACHIDONOYLGLYCEROPHOSPHOETHANOLAMINE							773961_UNIQUE	UM_Target_ID
# ARACHIDONOYLGLYCEROPHOSPHOINOSITOL							775736_UNIQUE	UM_Target_ID
# ARGININE				232		C02385	770820_SECONDARY	UM_Target_ID
# ASPARTATE				424		C16433	771119_UNIQUE	UM_Target_ID
# AZELAIC ACID				2266		C08261	771243_UNIQUE	UM_Target_ID
# B-ALANYL-N(PAI)-METHYL-L-HISTIDINE				112072		C01262	771080_UNIQUE	UM_Target_ID
# BEHENIC ACID				8215		C08281	771104_UNIQUE	UM_Target_ID
# BENZOATE				243		C00180	770974_UNIQUE	UM_Target_ID
# BILIVERDIN				5280353		C00500	771079_SECONDARY	UM_Target_ID
# BOC-A-(1-NAPHTHYLMETHYL)-DL-PRO-OH							771043_UNIQUE	UM_Target_ID
# BOC-ASN				82035		C01410	771273_PRIMARY_NOT_UNIQUE	UM_Target_ID
# BOC-ASP-OH				302432			775185_SECONDARY	UM_Target_ID
# BOC-MET-OH				111051			771122_UNIQUE	UM_Target_ID
# BOC-PHE-OH				77857			771306_UNIQUE	UM_Target_ID
# BOC-PRO-OH				85083			771431_SECONDARY	UM_Target_ID
# BOC-THR-OH				45357648			771440_UNIQUE	UM_Target_ID
# [C13] METHIONINE				876		C01733	771199_PRIMARY_NOT_UNIQUE	UM_Target_ID
# [C13] PHENYLALANINE				994		C02057	771201_PRIMARY	UM_Target_ID
# [C13] TYROSINE				1153		C01536	771200_PRIMARY_NOT_UNIQUE	UM_Target_ID
# [C13] VALINE				247		C00719	771176_PRIMARY_NOT_UNIQUE	UM_Target_ID
# CAPRYLIC ACID				379		C06423	771091_UNIQUE	UM_Target_ID
# CARNOSINE				439224		C00386	771221_SECONDARY	UM_Target_ID
# CATECHOL				289		C00090	771129_UNIQUE	UM_Target_ID
# CHENODEOXYCHOLATE				10133		C02528	771089_UNIQUE	UM_Target_ID
# CHOLATE				221493		C00695	770971_UNIQUE	UM_Target_ID
# CHOLESTEROL				5997		C00187	778148_UNIQUE	UM_Target_ID
# CHOLESTEROL SULFATE				65076			780248_UNIQUE	UM_Target_ID
# CINNAMIC ACID				5372954		C10438	771036_UNIQUE	UM_Target_ID
# CIS-7,10,13,16-DOCOSATETRAENOIC ACID				5497181			771151_UNIQUE	UM_Target_ID
# CITRATE				311		C00158	771156_PRIMARY	UM_Target_ID
# CITRULLINE				9750		C00327	774891_SECONDARY	UM_Target_ID
# CORTICOSTERONE				5753		C02140	771309_PRIMARY	UM_Target_ID
# CYCLOHEPTANECARBOXYLIC ACID				15091		C12104	771268_UNIQUE	UM_Target_ID
# CYS-GLY				439498		C01419	771276_UNIQUE	UM_Target_ID
# CYSTATHIONINE				10104953		C00542	771290_UNIQUE	UM_Target_ID
# DECANOATE				2969		C01571	771040_UNIQUE	UM_Target_ID
# DEHYDROISOANDROSTERONE 3-SULFATE				12594		C04555	771315_UNIQUE	UM_Target_ID
# DEOXYCORTICOSTERONE ACETATE				5952		C14554	771098_PRIMARY	UM_Target_ID
# DESMETHYLNAPROXEN SULFATE							777122_UNIQUE	UM_Target_ID
# DIETHYL 2-METHYL-3-OXOSUCCINATE				97750		C04067	771320_UNIQUE	UM_Target_ID
# DIHEXOSE							771456_SECONDARY	UM_Target_ID
# DIHOMO-LINOLEATE				6439848		C16525	773539_UNIQUE	UM_Target_ID
# DIHOMO-LINOLENATE				5280581		C03242	774630_UNIQUE	UM_Target_ID
# DIHYDROXYACETONE PHOSPHATE				668		C00111	770997_UNIQUE	UM_Target_ID
# DIMETHYLXANTHINE				185974			777148_SECONDARY	UM_Target_ID
# DOCOSAHEXAENOIC ACID				445580		C06429	771266_PRIMARY	UM_Target_ID
# DOCOSAPENTAENOATE				5497182		C16513	777922_UNIQUE	UM_Target_ID
# DODECANEDIOATE				12736		C02678	777951_UNIQUE	UM_Target_ID
# DODECENOATE							774990_UNIQUE	UM_Target_ID
# DOPAMINE 3-O-SULFATE				122136		C13690	776196_UNIQUE	UM_Target_ID
# ERUCIC ACID				5281116		C08316	771149_UNIQUE	UM_Target_ID
# ESTRADIOL-17BETA				5757		C00951	771332_UNIQUE	UM_Target_ID
# FORMYLANTHRANILATE				101399		C05653	775206_UNIQUE	UM_Target_ID
# FORMYL-L-METHIONINE				6995182		C03145	771365_PRIMARY	UM_Target_ID
# FRUCTOSE 1,6-BIPHOSPHATE				172313		C00354	771220_PRIMARY	UM_Target_ID
# FUMARIC ACID				444972		C00122	771185_UNIQUE	UM_Target_ID
# GAMA-L-GLUTAMYL-L-ALANINE							778042_UNIQUE	UM_Target_ID
# GAMMA-LINOLENIC ACID				5280933		C06426	770984_UNIQUE	UM_Target_ID
# GERANYL PYROPHOSPHATE				447277		C00353	771063_UNIQUE	UM_Target_ID
# GLUCURONOLACTONE				439782		C02670	771302_UNIQUE	UM_Target_ID
# GLUTAMIC ACID				611		C00302	771454_SECONDARY	UM_Target_ID
# GLUTAMINE				738		C00303	771400_SECONDARY	UM_Target_ID
# GLYCERIC ACID				439194		C00258	771001_SECONDARY	UM_Target_ID
# GLYCEROL PHOSPHATE							771464_UNIQUE	UM_Target_ID
# GLYCOCHOLATE				10140		C01921	771126_SECONDARY	UM_Target_ID
# GLYCODEOXYCHOLATE / GLYCOCHENODEOXYCHOLATE				22833539		C05464	773834_UNIQUE	UM_Target_ID
# GLYCOLITHOCHOLIC ACID ETHYL ESTER				16219441			771325_PRIMARY	UM_Target_ID
# GLYOXAL				7860		C14448	771369_UNIQUE	UM_Target_ID
# GLYOXYLATE				760		C00048	771239_UNIQUE	UM_Target_ID
# GUANIDINOACETATE				763		C00581	770860_UNIQUE	UM_Target_ID
# GULONO-1,4-LACTONE				165105		C05410	771364_UNIQUE	UM_Target_ID
# HEPTANOIC ACID				12222843			771316_UNIQUE	UM_Target_ID
# HEXACOSANOIC ACID				10469			770909_UNIQUE	UM_Target_ID
# HEXADECANEDIOATE				10459		C19615	776926_UNIQUE	UM_Target_ID
# HEXANOATE				8892		C01585	771183_UNIQUE	UM_Target_ID
# HEXITOL				5460044			771459_UNIQUE	UM_Target_ID
# HEXURONIC ACID							771468_UNIQUE	UM_Target_ID
# HIPPURATE				464		C01586	771188_SECONDARY	UM_Target_ID
# HYDROXYACETAMINOPHEN SULFATE							776219_UNIQUE	UM_Target_ID
# HYDROXYBENZOIC ACID				135			771409_UNIQUE	UM_Target_ID
# HYDROXYDECANOATE							773589_UNIQUE	UM_Target_ID
# HYDROXYISOVALERATE							775076_UNIQUE	UM_Target_ID
# HYPOXANTHINE				790		C00262	771216_SECONDARY	UM_Target_ID
# INDICAN				92769		C08481	771374_UNIQUE	UM_Target_ID
# INDOLE-3-ACETIC ACID				802		C00954	770917_SECONDARY	UM_Target_ID
# INDOLEPROPIONATE							777648_UNIQUE	UM_Target_ID
# INOSINE				6021		C00294	771177_SECONDARY	UM_Target_ID
# INOSINE 5`-TRIPHOSPHATE				8583		C00081	771444_UNIQUE	UM_Target_ID
# ISOLEUCINE/LEUCINE				6306		C00407	775175_UNIQUE	UM_Target_ID
# LACTOYLGLUTATHIONE				440018		C03451	773651_UNIQUE	UM_Target_ID
# LAURIC ACID				3893		C02679	771111_UNIQUE	UM_Target_ID
# LIGNOCERIC ACID				11197		C08320	771267_UNIQUE	UM_Target_ID
# LINOLEATE				5280450		C01595	780637_UNIQUE	UM_Target_ID
# LINOLEOYLGLYCEROPHOSPHOETHANOLAMINE							776365_UNIQUE	UM_Target_ID
# MALATE				525		C00711	771117_UNIQUE	UM_Target_ID
# MALONATE				867		C00383	771421_UNIQUE	UM_Target_ID
# MELATONIN				896		C01598	771226_SECONDARY	UM_Target_ID
# MERCAPTOPYRUVATE				98		C00957	770847_UNIQUE	UM_Target_ID
# METHIONINE				876		C01733	771102_SECONDARY	UM_Target_ID
# METHYL BETA-D-GALACTOSIDE				94214		C03619	770930_PRIMARY	UM_Target_ID
# MYRISTIC ACID				11005		C06424	771103_UNIQUE	UM_Target_ID
# MYRISTOLEIC ACID				5281119		C08322	771304_UNIQUE	UM_Target_ID
# N-ACETYL-D-GALACTOSAMINE				35717		C01132	771007_PRIMARY	UM_Target_ID
# N-ACETYL-DL-GLUTAMIC ACID				185			771008_PRIMARY	UM_Target_ID
# N-ACETYL-D-TRYPTOPHAN				439917		C03137	771299_PRIMARY	UM_Target_ID
# N-ACETYLGLYCINE				10972			770822_UNIQUE	UM_Target_ID
# N-ACETYL-L-PHENYLALANINE				74839		C03519	770867_PRIMARY	UM_Target_ID
# N-ACETYLNEURAMINATE				439197		C00270	771157_PRIMARY	UM_Target_ID
# N-BENZYLOXYCARBONYLGLYCINE				14349		C03710	777486_UNIQUE	UM_Target_ID
# N-CYCLOHEXYLSULFAMIC ACID				7533			770973_PRIMARY	UM_Target_ID
# N-FORMYLGLYCINE				75606			771382_SECONDARY	UM_Target_ID
# N-METHYLTRYPTAMINE				6088		C06213	770889_UNIQUE	UM_Target_ID
# N-OLEOYLGLYCINE				6436908			776954_UNIQUE	UM_Target_ID
# NONADECANOATE / METHYLSTEARATE (*)				12591		C16535	780488_UNIQUE	UM_Target_ID
# NONANOATE				8158		C01601	770967_UNIQUE	UM_Target_ID
# N(PAI)-METHYL-L-HISTIDINE				64969		C01152	774757_UNIQUE	UM_Target_ID
# OCTADECANEDIOATE				70095			778157_UNIQUE	UM_Target_ID
# OLEATE				445639		C00712	780634_UNIQUE	UM_Target_ID
# OLEOYLGLYCEROPHOSPHOETHANOLAMINE							773204_UNIQUE	UM_Target_ID
# ORNITHINE				71082		C00515	770902_UNIQUE	UM_Target_ID
# OROTATE				967		C00295	771231_PRIMARY	UM_Target_ID
# OXALOSUCCINATE				972		C05379	775327_UNIQUE	UM_Target_ID
# P-ACETAMIDOPHENYLGLUCURONIDE							775192_UNIQUE	UM_Target_ID
# PALMITIC ACID				985		C00249	780639_UNIQUE	UM_Target_ID
# PALMITOYLGLYCEROPHOSPHOETHANOLAMINE  / PALMITOYLPLASMENYLETHANOLAMINE							774032_UNIQUE	UM_Target_ID
# PALMITOYLGLYCEROPHOSPHOINOSITOL							776902_UNIQUE	UM_Target_ID
# PANTOATE				439251		C00522	771158_UNIQUE	UM_Target_ID
# PENTITOL				827		CA1511	771408_SECONDARY	UM_Target_ID
# PHENYLACETATE				999		C07086	773812_PRIMARY	UM_Target_ID
# PHENYLPYRUVATE				997		C00166	771323_UNIQUE	UM_Target_ID
# PHOSPHOCREATINE				587		C02305	771344_UNIQUE	UM_Target_ID
# PHOSPHO(ENOL)PYRUVIC ACID				1005		C00074	771003_UNIQUE	UM_Target_ID
# PHTHALATE				1017		C01606	770893_SECONDARY	UM_Target_ID
# PREGN STEROID MONOSULFATE				105074		C18044	774508_UNIQUE	UM_Target_ID
# PROGESTERONE				5994		C00410	771264_UNIQUE	UM_Target_ID
# PROSTAGLANDIN E1				214		C04741	778327_UNIQUE	UM_Target_ID
# PROSTAGLANDIN G2				5280883		C05956	776922_UNIQUE	UM_Target_ID
# PYRIDINE-2,3-DICARBOXYLATE				1066		C03722	771285_UNIQUE	UM_Target_ID
# PYRIDOXAL				1050		C00250	771208_SECONDARY	UM_Target_ID
# PYRIDOXINE				1054		C00314	771411_PRIMARY	UM_Target_ID
# PYRUVATE				1060		C00022	771065_UNIQUE	UM_Target_ID
# RIBOFLAVIN				493570		C00255	770881_SECONDARY	UM_Target_ID
# ROSMARINIC ACID				5281792		C01850	771105_PRIMARY	UM_Target_ID
# SALICYLIC ACID				338			771249_UNIQUE	UM_Target_ID
# SALICYLURIC GLUCURONIDE							776194_UNIQUE	UM_Target_ID
# S-CARBOXYMETHYL-L-CYSTEINE				193653		C03727	771380_UNIQUE	UM_Target_ID
# (S)-DIHYDROOROTATE				648		C00337	771420_PRIMARY	UM_Target_ID
# SERINE				617		C00716	771402_UNIQUE	UM_Target_ID
# S-HEXYL-GLUTATHIONE				97536		C02886	770932_PRIMARY	UM_Target_ID
# (S)-LACTATE				107689		C00186	770816_UNIQUE	UM_Target_ID
# SPHINGOSINE 1-PHOSPHATE				5283560		C06124	776446_UNIQUE	UM_Target_ID
# STACHYOSE				439531		C01613	771439_SECONDARY	UM_Target_ID
# STEARIDONATE				5282837		C16300	777765_UNIQUE	UM_Target_ID
# STEAROYLGLYCEROPHOSPHOETHANOLAMINE							774044_UNIQUE	UM_Target_ID
# STEAROYLGLYCEROPHOSPHOETHANOLAMINE_2							776026_UNIQUE	UM_Target_ID
# TAURINE				1123		C00245	771155_PRIMARY	UM_Target_ID
# TAUROCHENODEOXYCHOLATE				387316		C05465	773826_UNIQUE	UM_Target_ID
# TAUROCHOLATE				6675		C05122	773806_UNIQUE	UM_Target_ID
# TAUROLITHOCHOLATE				439763		C02592	771108_UNIQUE	UM_Target_ID
# TESTOSTERONE				6013		C00535	771110_SECONDARY	UM_Target_ID
# THIOPURINE S-METHYLETHER				5778		C03542	771128_SECONDARY	UM_Target_ID
# THREONATE				151152		C01620	775077_UNIQUE	UM_Target_ID
# THYMIDINE				5789		C00214	771180_SECONDARY	UM_Target_ID
# THYROTROPIN RELEASING HORMONE				638678		C03958	771293_UNIQUE	UM_Target_ID
# THYROXINE				5819		C01829	770970_SECONDARY	UM_Target_ID
# TRIDECANOIC ACID				12530			771263_UNIQUE	UM_Target_ID
# TRYPTOPHAN				6305		C00078	777067_UNIQUE	UM_Target_ID
# URACIL				1174		C00106	771100_UNIQUE	UM_Target_ID
# URATE				1175		C00366	771415_SECONDARY	UM_Target_ID
# URIDINE				6029		C00299	771217_SECONDARY	UM_Target_ID
# UROCORTISONE				618110		C05470	776444_UNIQUE	UM_Target_ID
# URSODIOL				127601		C07880	771075_SECONDARY	UM_Target_ID
# XANTHINE				1188		C00385	771422_SECONDARY	UM_Target_ID
# XANTHOSINE 5'-MONOPHOSPHATE				73323		C00655	771194_PRIMARY	UM_Target_ID
# XYLONATE				6602431		C00502	780305_UNIQUE	UM_Target_ID
# 11BETA,21-DIHYDROXY-5BETA-PREGNANE-3,20-DIONE (*)
# 13(S)-HPODE (*)
# 15(S)-HETE (*)
# 2-CARBOXY-2,3-DIHYDRO-5,6-DIHYDROXYINDOLE (*)
# 2-HYDROXYGLUTARATE (*)
# 2-HYDROXYSTEARATE (*)
# 2-OXO-3-HYDROXY-4-PHOSPHOBUTANOATE (*)
# 3-METHYL-2-OXOBUTANOIC ACID (*)
# 3ALPHA,7ALPHA,12ALPHA,26-TETRAHYDROXY-5BETA-CHOLESTANE (*)
# 3ALPHA,7ALPHA,12ALPHA-TRIHYDROXY-5BETA-CHOLESTANOATE (*)
# 3ALPHA,7ALPHA-DIHYDROXY-5BETA-CHOLESTANATE (*)
# 4-(2-AMINO-3-HYDROXYPHENYL)-2,4-DIOXOBUTANOATE (*)
# 4-ANDROSTEN-3BETA,17BETA-DIOL DISULFATE (*)
# 4-OXOGLUTARAMATE (*)
# 4-VINYLPHENOL SULFATE (*)
# 7-ALPHA-HYDROXY-3-OXO-4-CHOLESTENOATE (*)
# 9(10)-EPOME (*)
# ACONITATE (*)
# ALPHA-TOCOPHEROL (*)
# ANDROSTERONE GLUCURONIDE (*)
# ARACHIDONOYLGLYCEROPHOSPHOETHANOLAMINE (*)
# ARACHIDONOYLGLYCEROPHOSPHOINOSITOL (*)
# CHOLESTEROL (*)
# DESMETHYLNAPROXEN SULFATE (*)
# DIHOMO-LINOLEATE (*)
# DIHOMO-LINOLENATE (*)
# DOCOSAPENTAENOATE (*)
# DODECANEDIOATE (*)
# DODECENOATE (*)
# DOPAMINE 3-O-SULFATE (*)
# FORMYLANTHRANILATE (*)
# GAMA-L-GLUTAMYL-L-ALANINE (*)
# GLYCODEOXYCHOLATE / GLYCOCHENODEOXYCHOLATE  (*)
# HEXADECANEDIOATE (*)
# HYDROXYACETAMINOPHEN SULFATE (*)
# HYDROXYDECANOATE (*)
# HYDROXYISOVALERATE (*)
# INDOLEPROPIONATE (*)
# ISOLEUCINE/LEUCINE (*)
# LACTOYLGLUTATHIONE (*)
# LINOLEOYLGLYCEROPHOSPHOETHANOLAMINE (*)
# N(PAI)-METHYL-L-HISTIDINE (*)
# OCTADECANEDIOATE (*)
# OLEOYLGLYCEROPHOSPHOETHANOLAMINE (*)
# OXALOSUCCINATE (*)
# P-ACETAMIDOPHENYLGLUCURONIDE (*)
# PALMITOYLGLYCEROPHOSPHOETHANOLAMINE  / PALMITOYLPLASMENYLETHANOLAMINE  (*)
# PALMITOYLGLYCEROPHOSPHOINOSITOL (*)
# PHENYLACETATE (*)
# PREGN STEROID MONOSULFATE (*)
# PROSTAGLANDIN E1 (*)
# PROSTAGLANDIN G2 (*)
# SALICYLURIC GLUCURONIDE (*)
# SPHINGOSINE 1-PHOSPHATE (*)
# STEARIDONATE (*)
# STEAROYLGLYCEROPHOSPHOETHANOLAMINE (*)
# STEAROYLGLYCEROPHOSPHOETHANOLAMINE (*)_2
# TAUROCHENODEOXYCHOLATE (*)
# TAUROCHOLATE (*)
# THREONATE (*)
# TRYPTOPHAN (*)
# UROCORTISONE (*)
# XANTHOSINE 5`-MONOPHOSPHATE
# XYLONATE (*)
# METABOLITES_END
# #END

# %% [raw]
# * Print entire file in ``JSON`` format.

# %%
mwfile.print_file(file_format="json")
# Out:
# {
#     "METABOLOMICS WORKBENCH": {
#         "STUDY_ID": "ST000017",
#         "ANALYSIS_ID": "AN000035",
#         "PROJECT_ID": "PR000016",
#         "VERSION": "1",
#         "CREATED_ON": "2016-09-17"
#     },
#     "PROJECT": {
#         "PROJECT_TITLE": "Rat Stamina Studies",
#         "PROJECT_TYPE": "Feeding",
#         "PROJECT_SUMMARY": "Stamina in rats",
#         "INSTITUTE": "University of Michigan",
#         "DEPARTMENT": "Internal Medicine",
#         "LABORATORY": "Burant Lab",
#         "LAST_NAME": "Beecher",
#         "FIRST_NAME": "Chris",
#         "ADDRESS": "-",
#         "EMAIL": "chrisbee@med.umich.edu",
#         "PHONE": "1-530-754-8258",
#         "FUNDING_SOURCE": "NIH: R01 DK077200"
#     },
#     "STUDY": {
#         "STUDY_TITLE": "Rat HCR/LCR Stamina Study",
#         "STUDY_TYPE": "LC-MS analysis",
#         "STUDY_SUMMARY": "To determine the basis of running capacity and health differences in outbread N/NIH rats selected for high capacity (HCR) and low capacity (LCR) running (a for VO2max) (see:Science. 2005 Jan 21;307(5708):418-20). Plasma collected at 12 of age in generation 28 rats after ad lib feeding or 40% caloric restriction at week 8 of age. All animals fasted 4 hours prior to collection between 5-8",
#         "INSTITUTE": "University of Michigan",
#         "DEPARTMENT": "Internal Medicine",
#         "LABORATORY": "Burant Lab (MMOC)",
#         "LAST_NAME": "Qi",
#         "FIRST_NAME": "Nathan",
#         "ADDRESS": "-",
#         "EMAIL": "nathanqi@med.umich.edu",
#         "PHONE": "734-232-0815",
#         "NUM_GROUPS": "2",
#         "TOTAL_SUBJECTS": "42"
#     },
#     "SUBJECT": {
#         "SUBJECT_TYPE": "Animal",
#         "SUBJECT_SPECIES": "Rattus norvegicus",
#         "TAXONOMY_ID": "10116",
#         "GENOTYPE_STRAIN": "Low Capacity Running | High Capacity Running",
#         "SPECIES_GROUP": "Mammal"
#     },
#     "SUBJECT_SAMPLE_FACTORS": [
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009477",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "High"
#             },
#             "Additional sample data": {
#                 "Additional detail key": "Additional detail value"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009478",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009479",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009480",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009481",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009500",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009501",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009502",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009503",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009470",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009471",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009472",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009473",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009474",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009475",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009494",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009495",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009496",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009497",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009498",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009499",
#             "Factors": {
#                 "Feeeding": "Ad lib",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009488",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009489",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009490",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009491",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009492",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009493",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009509",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009510",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009511",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009512",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009513",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009514",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "High"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009482",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009483",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009484",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009486",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009504",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009505",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009506",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009507",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "Low"
#             }
#         },
#         {
#             "Subject ID": "-",
#             "Sample ID": "S00009508",
#             "Factors": {
#                 "Feeeding": "Calorie restricted",
#                 "Running Capacity": "Low"
#             }
#         }
#     ],
#     "COLLECTION": {
#         "COLLECTION_SUMMARY": "-",
#         "SAMPLE_TYPE": "Serum",
#         "VOLUMEORAMOUNT_COLLECTED": "50 ul"
#     },
#     "TREATMENT": {
#         "TREATMENT_SUMMARY": "ad lib feeding | Calorie restricted feeding"
#     },
#     "SAMPLEPREP": {
#         "SAMPLEPREP_SUMMARY": "-",
#         "SAMPLEPREP_PROTOCOL_FILENAME": "EX00166-Sample_preparation_protocol.pdf"
#     },
#     "CHROMATOGRAPHY": {
#         "CHROMATOGRAPHY_SUMMARY": "Negative ion detection",
#         "CHROMATOGRAPHY_TYPE": "Reversed phase",
#         "INSTRUMENT_NAME": "Agilent 1200",
#         "COLUMN_NAME": "Waters Acquity HSS T3 reversed-phase",
#         "METHODS_FILENAME": "EX00166-LCMS-method.pdf",
#         "COLUMN_TEMPERATURE": "40C",
#         "FLOW_GRADIENT": "0-0.5 min 1% B, 0.5-2 min 1-99% B, 2-6 min 99% B, 6-9 min 1% B.",
#         "FLOW_RATE": "0.35 mL/min",
#         "SOLVENT_A": "100% water with 0.1% ammonium bicarbonate",
#         "SOLVENT_B": "100% methanol with 0.1% ammonium bicarbonate"
#     },
#     "ANALYSIS": {
#         "ANALYSIS_TYPE": "MS",
#         "ACQUISITION_PARAMETERS_FILE": "EX00166-LCMS-method.pdf",
#         "PROCESSING_PARAMETERS_FILE": "EX00166-Data_analysis-method.pdf",
#         "DETECTOR_TYPE": "LC / Electro-spray /QTOF MS Negative"
#     },
#     "MS": {
#         "INSTRUMENT_NAME": "Agilent 6530 QTOF",
#         "INSTRUMENT_TYPE": "QTOF",
#         "MS_TYPE": "ESI",
#         "ION_MODE": "NEGATIVE",
#         "MS_COMMENTS": "Reference masses 62.0009 and 981.9956 m/z.",
#         "CAPILLARY_VOLTAGE": "3500V",
#         "ION_SOURCE_TEMPERATURE": "350 C"
#     },
#     "MS_METABOLITE_DATA": {
#         "Units": "peak area",
#         "Data": [
#             {
#                 "Metabolite": "11BETA_21-DIHYDROXY-5BETA-PREGNANE-3_20-DIONE",
#                 "S00009477": "",
#                 "S00009478": "",
#                 "S00009479": "",
#                 "S00009480": "",
#                 "S00009481": "",
#                 "S00009500": "",
#                 "S00009501": "",
#                 "S00009502": "",
#                 "S00009503": "",
#                 "S00009470": "",
#                 "S00009471": "",
#                 "S00009472": "",
#                 "S00009473": "",
#                 "S00009474": "476477.0000",
#                 "S00009475": "",
#                 "S00009494": "",
#                 "S00009495": "",
#                 "S00009496": "",
#                 "S00009497": "",
#                 "S00009498": "",
#                 "S00009499": "",
#                 "S00009488": "",
#                 "S00009489": "",
#                 "S00009490": "1654198.0000",
#                 "S00009491": "",
#                 "S00009492": "",
#                 "S00009493": "",
#                 "S00009509": "",
#                 "S00009510": "",
#                 "S00009511": "",
#                 "S00009512": "",
#                 "S00009513": "",
#                 "S00009514": "",
#                 "S00009482": "",
#                 "S00009483": "",
#                 "S00009484": "",
#                 "S00009486": "",
#                 "S00009504": "",
#                 "S00009505": "",
#                 "S00009506": "",
#                 "S00009507": "",
#                 "S00009508": ""
#             },
#             {
#                 "Metabolite": "11-BETA-HYDROXYANDROST-4-ENE-3_17-DIONE",
#                 "S00009477": "41390.0000",
#                 "S00009478": "",
#                 "S00009479": "212727.0000",
#                 "S00009480": "252256.0000",
#                 "S00009481": "",
#                 "S00009500": "",
#                 "S00009501": "229139.0000",
#                 "S00009502": "",
#                 "S00009503": "227793.0000",
#                 "S00009470": "267879.0000",
#                 "S00009471": "243325.0000",
#                 "S00009472": "180614.0000",
#                 "S00009473": "267597.0000",
#                 "S00009489": "22914206.0000",
#                 "S00009490": "",
#                 "S00009491": "",
#                 "S00009492": "",
#                 "S00009493": "12692726.0000",
#                 "S00009509": "159843050.0000",
#                 "S00009510": "138001763.0000",
#                 "S00009511": "153686322.0000",
#                 "S00009512": "122851680.0000",
#                 "S00009513": "92718735.0000",
#                 "S00009514": "192198832.0000",
#                 "S00009482": "105472067.0000",
#                 "S00009483": "25710586.0000",
#                 "S00009484": "128200875.0000",
#                 "S00009486": "",
#                 "S00009504": "",
#                 "S00009505": "21986353.0000",
#                 "S00009506": "",
#                 "S00009507": "",
#                 "S00009508": "261015093.0000"
#             },
#             {
#                 "Metabolite": "1-AMINOCYCLOPROPANE-1-CARBOXYLATE",
#                 "S00009477": "",
#                 "S00009478": "",
#                 "S00009479": "",
#                 "S00009480": "",
#                 "S00009481": "",
#                 "S00009500": "",
#                 "S00009501": "",
#                 "S00009502": "",
#                 "S00009503": "",
#                 "S00009470": "",
#                 "S00009471": "",
#                 "S00009472": "",
#                 "S00009473": "",
#                 "S00009474": "",
#                 "S00009475": "",
#                 "S00009494": "",
#                 "S00009495": "",
#                 "S00009496": "",
#                 "S00009497": "",
#                 "S00009498": "",
#                 "S00009499": "",
#                 "S00009488": "",
#                 "S00009489": "",
#                 "S00009490": "",
#                 "S00009491": "",
#                 "S00009492": "",
#                 "S00009493": "",
#                 "S00009509": "",
#                 "S00009510": "10471.0000",
#                 "S00009511": "",
#                 "S00009512": "",
#                 "S00009513": "23868.0000",
#                 "S00009514": "",
#                 "S00009482": "21134.0000",
#                 "S00009483": "37197.0000",
#                 "S00009484": "11205.0000",
#                 "S00009486": "",
#                 "S00009504": "",
#                 "S00009505": "",
#                 "S00009506": "",
#                 "S00009507": "",
#                 "S00009508": ""
#             },
#             {
#                 "Metabolite": "1-HYDROXY-2-NAPHTHOATE",
#                 "S00009477": "",
#                 "S00009478": "",
#                 "S00009479": "",
#                 "S00009480": "11728.0000",
#                 "S00009481": "",
#                 "S00009500": "",
#                 "S00009501": "",
#                 "S00009502": "38104.0000",
#                 "S00009503": "",
#                 "S00009470": "52140.0000",
#                 "S00009471": "",
#                 "S00009472": "",
#                 "S00009473": "43663.0000",
#                 "S00009474": "",
#                 "S00009475": "",
#                 "S00009494": "",
#                 "S00009495": "",
#                 "S00009496": "56942.0000",
#                 "S00009497": "",
#                 "S00009498": "57147.0000",
#                 "S00009499": "",
#                 "S00009488": "10001.0000",
#                 "S00009489": "",
#                 "S00009490": "",
#                 "S00009491": "",
#                 "S00009492": "55219.0000",
#                 "S00009493": "",
#                 "S00009509": "",
#                 "S00009510": "25355.0000",
#                 "S00009511": "58888.0000",
#                 "S00009512": "",
#                 "S00009513": "14856.0000",
#                 "S00009514": "",
#                 "S00009482": "",
#                 "S00009483": "",
#                 "S00009484": "",
#                 "S00009486": "",
#                 "S00009504": "",
#                 "S00009505": "63898.0000",
#                 "S00009506": "",
#                 "S00009507": "",
#                 "S00009508": ""
#             },
#             {
#                 "Metabolite": "2_3-DIPHOSPHO-D-GLYCERIC ACID",
#                 "S00009477": "",
#                 "S00009478": "",
#                 "S00009479": "",
#                 "S00009480": "",
#                 "S00009481": "",
#                 "S00009500": "",
#                 "S00009501": "",
#                 "S00009502": "",
#                 "S00009503": "",
#                 "S00009470": "21173.0000",
#                 "S00009471": "",
#                 "S00009472": "",
#                 "S00009473": "",
#                 "S00009474": "",
#                 "S00009475": "",
#                 "S00009494": "22944.0000",
#                 "S00009495": "",
#                 "S00009496": "",
#                 "S00009497": "",
#                 "S00009498": "",
#                 "S00009499": "",
#                 "S00009488": "",
#                 "S00009489": "",
#                 "S00009490": "23298.0000",
#                 "S00009491": "",
#                 "S00009492": "",
#                 "S00009493": "32359.0000",
#                 "S00009509": "",
#                 "S00009510": "",
#                 "S00009511": "",
#                 "S00009512": "",
#                 "S00009513": "",
#                 "S00009514": "",
#                 "S00009482": "",
#                 "S00009483": "",
#                 "S00009484": "",
#                 "S00009486": "",
#                 "S00009504": "",
#                 "S00009505": "16296.0000",
#                 "S00009506": "",
#                 "S00009507": "",
#                 "S00009508": ""
#             },
#             {
#                 "Metabolite": "2-CARBOXY-2_3-DIHYDRO-5_6-DIHYDROXYINDOLE",
#                 "S00009477": "",
#                 "S00009478": "1171972.0000",
#                 "S00009479": "",
#                 "S00009480": "",
#                 "S00009481": "",
#                 "S00009500": "",
#                 "S00009501": "",
#                 "S00009502": "",
#                 "S00009503": "",
#                 "S00009470": "",
#                 "S00009471": "",
#                 "S00009472": "",
#                 "S00009473": "",
#                 "S00009474": "13052.0000",
#                 "S00009475": "",
#                 "S00009494": "509175.0000",
#                 "S00009495": "",
#                 "S00009496": "",
#                 "S00009497": "",
#                 "S00009498": "",
#                 "S00009499": "",
#                 "S00009488": "",
#                 "S00009489": "",
#                 "S00009490": "1584578.0000",
#                 "S00009491": "",
#                 "S00009492": "1098809.0000",
#                 "S00009493": "1246822.0000",
#                 "S00009509": "",
#                 "S00009510": "",
#                 "S00009511": "377332.0000",
#                 "S00009512": "653153.0000",
#                 "S00009513": "1296183.0000",
#                 "S00009514": "369182.0000",
#                 "S00009482": "1309541.0000",
#                 "S00009483": "1474862.0000",
#                 "S00009484": "",
#                 "S00009486": "",
#                 "S00009504": "2970076.0000",
#                 "S00009505": "2320723.0000",
#                 "S00009506": "",
#                 "S00009507": "",
#                 "S00009508": "318905.0000"
#             },
#             {
#                 "Metabolite": "2`-DEOXYURIDINE 5`-TRIPHOSPHATE",
#                 "S00009477": "",
#                 "S00009478": "",
#                 "S00009479": "",
#                 "S00009480": "",
#                 "S00009481": "",
#                 "S00009500": "",
#                 "S00009501": "",
#                 "S00009502": "",
#                 "S00009503": "",
#                 "S00009470": "",
#                 "S00009471": "",
#                 "S00009472": "",
#                 "S00009473": "15645.0000",
#                 "S00009474": "",
#                 "S00009475": "",
#                 "S00009494": "",
#                 "S00009495": "",
#                 "S00009496": "",
#                 "S00009497": "",
#                 "S00009498": "",
#                 "S00009499": "",
#                 "S00009488": "",
#                 "S00009489": "",
#                 "S00009490": "",
#                 "S00009512": "819205.0000",
#                 "S00009513": "1159906.0000",
#                 "S00009514": "413813.0000",
#                 "S00009482": "1167676.0000",
#                 "S00009483": "",
#                 "S00009484": "370055.0000",
#                 "S00009486": "383999.0000",
#                 "S00009504": "968622.0000",
#                 "S00009505": "693011.0000",
#                 "S00009506": "",
#                 "S00009507": "974805.0000",
#                 "S00009508": "369845.0000"
#             },
#             {
#                 "Metabolite": "3ALPHA_7ALPHA_12ALPHA-TRIHYDROXY-5BETA-CHOLESTANOATE",
#                 "S00009477": "789137.0000",
#                 "S00009478": "715731.0000",
#                 "S00009479": "1009222.0000",
#                 "S00009480": "786537.0000",
#                 "S00009481": "1627535.0000",
#                 "S00009500": "613194.0000",
#                 "S00009501": "",
#                 "S00009502": "",
#                 "S00009503": "532921.0000",
#                 "S00009470": "725645.0000",
#                 "S00009471": "514505.0000",
#                 "S00009472": "643114.0000",
#                 "S00009473": "774837.0000",
#                 "S00009474": "",
#                 "S00009475": "630549.0000",
#                 "S00009494": "288685.0000",
#                 "S00009495": "2842014.0000",
#                 "S00009496": "",
#                 "S00009497": "",
#                 "S00009498": "",
# ...
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "4-OXOGLUTARAMATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "4-VINYLPHENOL SULFATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "7-ALPHA-HYDROXY-3-OXO-4-CHOLESTENOATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "9(10)-EPOME (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "ACONITATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "ALPHA-TOCOPHEROL (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "ANDROSTERONE GLUCURONIDE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "ARACHIDONOYLGLYCEROPHOSPHOETHANOLAMINE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "ARACHIDONOYLGLYCEROPHOSPHOINOSITOL (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "CHOLESTEROL (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "DESMETHYLNAPROXEN SULFATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "DIHOMO-LINOLEATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "DIHOMO-LINOLENATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "DOCOSAPENTAENOATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "DODECANEDIOATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "DODECENOATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "DOPAMINE 3-O-SULFATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "FORMYLANTHRANILATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "GAMA-L-GLUTAMYL-L-ALANINE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "GLYCODEOXYCHOLATE / GLYCOCHENODEOXYCHOLATE  (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "HEXADECANEDIOATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "HYDROXYACETAMINOPHEN SULFATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "HYDROXYDECANOATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "HYDROXYISOVALERATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "INDOLEPROPIONATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "ISOLEUCINE/LEUCINE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "LACTOYLGLUTATHIONE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "LINOLEOYLGLYCEROPHOSPHOETHANOLAMINE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "N(PAI)-METHYL-L-HISTIDINE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "OCTADECANEDIOATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "OLEOYLGLYCEROPHOSPHOETHANOLAMINE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "OXALOSUCCINATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "P-ACETAMIDOPHENYLGLUCURONIDE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "PALMITOYLGLYCEROPHOSPHOETHANOLAMINE  / PALMITOYLPLASMENYLETHANOLAMINE  (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "PALMITOYLGLYCEROPHOSPHOINOSITOL (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "PHENYLACETATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "PREGN STEROID MONOSULFATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "PROSTAGLANDIN E1 (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "PROSTAGLANDIN G2 (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "SALICYLURIC GLUCURONIDE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "SPHINGOSINE 1-PHOSPHATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "STEARIDONATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "STEAROYLGLYCEROPHOSPHOETHANOLAMINE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "STEAROYLGLYCEROPHOSPHOETHANOLAMINE (*)_2",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "TAUROCHENODEOXYCHOLATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "TAUROCHOLATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "THREONATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "TRYPTOPHAN (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "UROCORTISONE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "XANTHOSINE 5`-MONOPHOSPHATE",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             },
#             {
#                 "Metabolite": "XYLONATE (*)",
#                 "moverz_quant": "",
#                 "ri": "",
#                 "ri_type": "",
#                 "pubchem_id": "",
#                 "inchi_key": "",
#                 "kegg_id": "",
#                 "other_id": ""
#             }
#         ]
#     }
# }

# %% [raw]
# * Print single block in ``mwTab`` format.

# %%
mwfile.print_block("STUDY", file_format="mwtab")
# Out:
# ST:STUDY_TITLE                   	Rat HCR/LCR Stamina Study
# ST:STUDY_TYPE                    	LC-MS analysis
# ST:STUDY_SUMMARY                 	To determine the basis of running capacity and health differences in outbread
# ST:STUDY_SUMMARY                 	N/NIH rats selected for high capacity (HCR) and low capacity (LCR) running (a for
# ST:STUDY_SUMMARY                 	VO2max) (see:Science. 2005 Jan 21;307(5708):418-20). Plasma collected at 12 of
# ST:STUDY_SUMMARY                 	age in generation 28 rats after ad lib feeding or 40% caloric restriction at week
# ST:STUDY_SUMMARY                 	8 of age. All animals fasted 4 hours prior to collection between 5-8
# ST:INSTITUTE                     	University of Michigan
# ST:DEPARTMENT                    	Internal Medicine
# ST:LABORATORY                    	Burant Lab (MMOC)
# ST:LAST_NAME                     	Qi
# ST:FIRST_NAME                    	Nathan
# ST:ADDRESS                       	-
# ST:EMAIL                         	nathanqi@med.umich.edu
# ST:PHONE                         	734-232-0815
# ST:NUM_GROUPS                    	2
# ST:TOTAL_SUBJECTS                	42

# %% [raw]
# * Print single block in ``JSON`` format.

# %%
mwfile.print_block("STUDY", file_format="json")
# Out:
# {
#     "STUDY_TITLE": "Rat HCR/LCR Stamina Study",
#     "STUDY_TYPE": "LC-MS analysis",
#     "STUDY_SUMMARY": "To determine the basis of running capacity and health differences in outbread N/NIH rats selected for high capacity (HCR) and low capacity (LCR) running (a for VO2max) (see:Science. 2005 Jan 21;307(5708):418-20). Plasma collected at 12 of age in generation 28 rats after ad lib feeding or 40% caloric restriction at week 8 of age. All animals fasted 4 hours prior to collection between 5-8",
#     "INSTITUTE": "University of Michigan",
#     "DEPARTMENT": "Internal Medicine",
#     "LABORATORY": "Burant Lab (MMOC)",
#     "LAST_NAME": "Qi",
#     "FIRST_NAME": "Nathan",
#     "ADDRESS": "-",
#     "EMAIL": "nathanqi@med.umich.edu",
#     "PHONE": "734-232-0815",
#     "NUM_GROUPS": "2",
#     "TOTAL_SUBJECTS": "42"
# }

# %% [raw]
# Writing data from a MWTabFile object into a file
# ------------------------------------------------
# Data from a :class:`~mwtab.mwtab.MWTabFile` can be written into file
# in original ``mwTab`` format or in equivalent JSON format using
# :meth:`~mwtab.mwtab.MWTabFile.write()`:
#
# * Writing into a ``mwTab`` formatted file:

# %%
with open("out/ST000017_AN000035_modified.txt", "w") as outfile:
    mwfile.write(outfile, file_format="mwtab")

# %% [raw]
# * Writing into a ``JSON`` file:

# %%
with open("out/ST000017_AN000035_modified.json", "w") as outfile:
    mwfile.write(outfile, file_format="json")

# %% [raw]
# Extracting Metadata and Metabolites from mwTab Files
# ----------------------------------------------------
#
# The :mod:`mwtab.mwextract` module can be used to extract metadata from ``mwTab``
# files. The module contains two main methods: 1)
# :meth:`~mwtab.mwtab.mwextract.extract_metadata()` which can be used to parse metadata
# values from a ``mwTab`` file, and 2)
# :meth:`~mwtab.mwtab.mwextract.extract_metabolites()` which can be used to gather a
# list of metabolites and samples containing the found metabolites from multiple
# ``mwTab`` files which contain a given metadata key value pair.
#
# Extracting Metadata Values
# **************************
#
# * Extracting metadata values from a given ``mwTab`` file:

# %%
from mwtab.mwextract import extract_metadata

extract_metadata(mwfile, ["STUDY_TYPE", "SUBJECT_TYPE"])
# Out:
# {'STUDY_TYPE': {'LC-MS analysis'}, 'SUBJECT_TYPE': {'Animal'}}

# %% [raw]
# Extracting Metabolites Values
# *****************************
#
# * Extracting metabolite information from multiple ``mwTab`` files:

# %%
from mwtab.mwextract import extract_metabolites, generate_matchers
from mwtab import read_files

mwtab_gen = read_files(
    "ST000017_AN000035.txt",
    "ST000040_AN000060.txt"
)

matchers = generate_matchers([
    ("ST:STUDY_TYPE",
    "LC-MS analysis")
])
extract_metabolites(mwtab_gen, matchers)
# Out:
# {'11BETA_21-DIHYDROXY-5BETA-PREGNANE-3_20-DIONE': {'ST000017': {'AN000035': {'S00009474',
#     'S00009490'}}},
#  '11-BETA-HYDROXYANDROST-4-ENE-3_17-DIONE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009477',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009490',
#     'S00009492',
#     'S00009494',
#     'S00009498',
#     'S00009501',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512'}}},
#  '13(S)-HPODE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009474',
#     'S00009477',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009492',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009508',
#     'S00009509',
#     'S00009511',
#     'S00009513',
#     'S00009514'}}},
#  '15(S)-HETE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '1-AMINOCYCLOPROPANE-1-CARBOXYLATE': {'ST000017': {'AN000035': {'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009510',
#     'S00009513'}}},
#  '1-HYDROXY-2-NAPHTHOATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009473',
#     'S00009480',
#     'S00009488',
#     'S00009492',
#     'S00009496',
#     'S00009498',
#     'S00009502',
#     'S00009505',
#     'S00009510',
#     'S00009511',
#     'S00009513'}}},
#  '2_3-DIPHOSPHO-D-GLYCERIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009490',
#     'S00009493',
#     'S00009494',
#     'S00009505'}}},
#  '2-CARBOXY-2_3-DIHYDRO-5_6-DIHYDROXYINDOLE': {'ST000017': {'AN000035': {'S00009474',
#     'S00009478',
#     'S00009482',
#     'S00009483',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009504',
#     'S00009505',
#     'S00009508',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '2`-DEOXYURIDINE 5`-TRIPHOSPHATE': {'ST000017': {'AN000035': {'S00009473'}}},
#  '2-HYDROXYBUTYRIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '2-HYDROXYGLUTARATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009501',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '2-HYDROXYSTEARATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '2-OXO-3-HYDROXY-4-PHOSPHOBUTANOATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '2-OXOADIPATE': {'ST000017': {'AN000035': {'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513'}}},
#  '2-OXOBUTANOATE': {'ST000017': {'AN000035': {'S00009472',
#     'S00009475',
#     'S00009477',
#     'S00009481',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009497',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009512'}}},
#  '3-(2-HYDROXYPHENYL)PROPANOATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3_4-DIHYDROXYBENZOATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009473',
#     'S00009474',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3_4-DIHYDROXYPHENYL GLYCOL': {'ST000017': {'AN000035': {'S00009488',
#     'S00009489',
#     'S00009495',
#     'S00009511'}}},
#  '3-(4-HYDROXYPHENYL)LACTATE': {'ST000017': {'AN000035': {'S00009475',
#     'S00009479',
#     'S00009483',
#     'S00009488',
#     'S00009513'}}},
#  '3ALPHA_7ALPHA_12ALPHA_26-TETRAHYDROXY-5BETA-CHOLESTANE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3ALPHA_7ALPHA_12ALPHA-TRIHYDROXY-5BETA-CHOLESTANOATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009490',
#     'S00009492',
#     'S00009494',
#     'S00009495',
#     'S00009499',
#     'S00009500',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009509',
#     'S00009510',
#     'S00009512',
#     'S00009514'}}},
#  '3ALPHA_7ALPHA-DIHYDROXY-5BETA-CHOLESTANATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009477',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009502',
#     'S00009503',
#     'S00009507',
#     'S00009509',
#     'S00009510',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3ALPHA-HYDROXY-5BETA-CHOLANATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3-CARBOXY-4-METHYL-5-PROPYL-2-FURANPROPANOATE': {'ST000017': {'AN000035': {'S00009471',
#     'S00009481',
#     'S00009483',
#     'S00009496',
#     'S00009502',
#     'S00009503',
#     'S00009507',
#     'S00009509',
#     'S00009512',
#     'S00009513'}}},
#  '3-HYDROXY-3-METHYLGLUTARATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3-HYDROXYANTHRANILATE': {'ST000017': {'AN000035': {'S00009479',
#     'S00009480',
#     'S00009484',
#     'S00009488',
#     'S00009490',
#     'S00009508',
#     'S00009511',
#     'S00009514'}}},
#  '3-HYDROXYBENZALDEHYDE': {'ST000017': {'AN000035': {'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009480',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009514'}}},
#  '3-HYDROXYBENZYL ALCOHOL': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3-HYDROXY-DL-KYNURENINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009472',
#     'S00009473',
#     'S00009478',
#     'S00009479',
#     'S00009483',
#     'S00009490',
#     'S00009495',
#     'S00009501',
#     'S00009507'}}},
#  '3-METHOXY-L-TYROSINE': {'ST000017': {'AN000035': {'S00009482',
#     'S00009483',
#     'S00009488',
#     'S00009502'}}},
#  '3-METHYL-2-OXINDOLE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3-METHYL-2-OXOBUTANOIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3-METHYL-2-OXOVALERIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '3-METHYLADENINE': {'ST000017': {'AN000035': {'S00009471',
#     'S00009472',
#     'S00009475',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009490',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009509',
#     'S00009511',
#     'S00009512'}}},
#  '3-NITRO-L-TYROSINE': {'ST000017': {'AN000035': {'S00009473',
#     'S00009489',
#     'S00009493',
#     'S00009494',
#     'S00009499',
#     'S00009500',
#     'S00009505',
#     'S00009512'}}},
#  '3-SULFINO-L-ALANINE': {'ST000017': {'AN000035': {'S00009483',
#     'S00009504',
#     'S00009507',
#     'S00009513'}}},
#  '4-(2-AMINO-3-HYDROXYPHENYL)-2_4-DIOXOBUTANOATE': {'ST000017': {'AN000035': {'S00009471',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009493',
#     'S00009495',
#     'S00009500',
#     'S00009501',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '4-ACETAMIDOBUTANOATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '4-AMINOBENZOATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009473',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009500',
#     'S00009501',
#     'S00009503',
#     'S00009504',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '4-ANDROSTEN-3BETA_17BETA-DIOL DISULFATE': {'ST000017': {'AN000035': {'S00009480',
#     'S00009481',
#     'S00009493',
#     'S00009499',
#     'S00009508'}}},
#  '4-HYDROXY-2-QUINOLINECARBOXYLIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '4-HYDROXY-3-METHOXY-BENZENEMETHANOL': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009474',
#     'S00009478',
#     'S00009479',
#     'S00009481',
#     'S00009483',
#     'S00009486',
#     'S00009490',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009501',
#     'S00009503',
#     'S00009505',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009512'}}},
#  '4-HYDROXY-3-METHOXYPHENYLGLYCOL': {'ST000017': {'AN000035': {'S00009477',
#     'S00009479',
#     'S00009482',
#     'S00009488',
#     'S00009507'}}},
#  '4-HYDROXYBENZALDEHYDE': {'ST000017': {'AN000035': {'S00009478',
#     'S00009490',
#     'S00009500',
#     'S00009501',
#     'S00009511',
#     'S00009514'}}},
#  '4-HYDROXYPHENYLACETATE': {'ST000017': {'AN000035': {'S00009479',
#     'S00009482',
#     'S00009483',
#     'S00009496',
#     'S00009501',
#     'S00009504',
#     'S00009511',
#     'S00009512'}}},
#  '4-OXOGLUTARAMATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '4-PYRIDOXATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '4-VINYLPHENOL SULFATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '5_6-DIHYDROURACIL': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '5-AMINOLEVULINIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009475',
#     'S00009482',
#     'S00009489',
#     'S00009492',
#     'S00009494',
#     'S00009497',
#     'S00009498',
#     'S00009510'}}},
#  '5-HYDROXYINDOLE-3-ACETIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '5-HYDROXY-L-TRYPTOPHAN': {'ST000017': {'AN000035': {'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009501',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513'}}},
#  '5-OXO-PROLINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '5-PHOSPHO-ALPHA-D-RIBOSE': {'ST000017': {'AN000035': {'S00009513'}}},
#  '6-HYDROXYNICOTINATE': {'ST000017': {'AN000035': {'S00009484',
#     'S00009489',
#     'S00009504',
#     'S00009505',
#     'S00009508',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009514'}}},
#  '6-PHOSPHOGLUCONIC ACID': {'ST000017': {'AN000035': {'S00009477',
#     'S00009490',
#     'S00009494',
#     'S00009513'}}},
#  '7-ALPHA-HYDROXY-3-OXO-4-CHOLESTENOATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '9(10)-EPOME': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'ACETYLENEDICARBOXYLATE': {'ST000017': {'AN000035': {'S00009478',
#     'S00009490',
#     'S00009495',
#     'S00009499',
#     'S00009508',
#     'S00009511',
#     'S00009512'}}},
#  'ACONITATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'ADENINE': {'ST000017': {'AN000035': {'S00009471',
#     'S00009472',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009483',
#     'S00009486',
#     'S00009489',
#     'S00009490',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009514'}}},
#  'ALDOSTERONE': {'ST000017': {'AN000035': {'S00009472',
#     'S00009484',
#     'S00009486',
#     'S00009490',
#     'S00009497',
#     'S00009498',
#     'S00009500',
#     'S00009508',
#     'S00009510',
#     'S00009511',
#     'S00009514'}}},
#  'ALPHA-TOCOPHEROL': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009499',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009514'}}},
#  'AMINOBUTANOIC ACID': {'ST000017': {'AN000035': {'S00009474',
#     'S00009477',
#     'S00009479',
#     'S00009496',
#     'S00009500',
#     'S00009502',
#     'S00009504',
#     'S00009508',
#     'S00009513',
#     'S00009514'}}},
#  'AMINOHYDROXYBUTANOIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'AMINOPENTANOIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'ANANDAMIDE': {'ST000017': {'AN000035': {'S00009477',
#     'S00009481',
#     'S00009489',
#     'S00009498',
#     'S00009505',
#     'S00009513'}}},
#  'ANDROSTERONE GLUCURONIDE': {'ST000017': {'AN000035': {'S00009492',
#     'S00009497',
#     'S00009503',
#     'S00009504',
#     'S00009509'}}},
#  'ANILINE-2-SULFONIC ACID': {'ST000017': {'AN000035': {'S00009503'}}},
#  'ARACHIDIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009474',
#     'S00009478',
#     'S00009479',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009499',
#     'S00009501',
#     'S00009503',
#     'S00009504',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009514'}}},
#  'ARACHIDONATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'ARACHIDONOYLGLYCEROPHOSPHOETHANOLAMINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'ARACHIDONOYLGLYCEROPHOSPHOINOSITOL': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009504',
#     'S00009505',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'ARGININE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'ASPARTATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009490',
#     'S00009492',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009514'}}},
#  'AZELAIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009474',
#     'S00009475',
#     'S00009479',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009490',
#     'S00009492',
#     'S00009497',
#     'S00009499',
#     'S00009504',
#     'S00009510'}}},
#  'B-ALANYL-N(PAI)-METHYL-L-HISTIDINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'BEHENIC ACID': {'ST000017': {'AN000035': {'S00009473',
#     'S00009479',
#     'S00009490',
#     'S00009492',
#     'S00009501'}}},
#  'BENZOATE': {'ST000017': {'AN000035': {'S00009488',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009514'}}},
#  'BILIVERDIN': {'ST000017': {'AN000035': {'S00009493', 'S00009499'}}},
#  'BOC-A-(1-NAPHTHYLMETHYL)-DL-PRO-OH': {'ST000017': {'AN000035': {'S00009472'}}},
#  'BOC-ASN': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'BOC-ASP-OH': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'BOC-MET-OH': {'ST000017': {'AN000035': {'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009494',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'BOC-PHE-OH': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'BOC-PRO-OH': {'ST000017': {'AN000035': {'S00009470',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009481',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009501',
#     'S00009502',
#     'S00009505',
#     'S00009508',
#     'S00009513',
#     'S00009514'}}},
#  'BOC-THR-OH': {'ST000017': {'AN000035': {'S00009492', 'S00009513'}}},
#  '[C13] METHIONINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '[C13] PHENYLALANINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009488',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009501',
#     'S00009508',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009514'}}},
#  '[C13] TYROSINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  '[C13] VALINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CAPRYLIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CARNOSINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009493',
#     'S00009494',
#     'S00009497',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CATECHOL': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CHENODEOXYCHOLATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CHOLATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CHOLESTEROL': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CHOLESTEROL SULFATE': {'ST000017': {'AN000035': {'S00009471',
#     'S00009474',
#     'S00009475',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CINNAMIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009479',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CIS-7_10_13_16-DOCOSATETRAENOIC ACID': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009513',
#     'S00009514'}}},
#  'CITRATE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009478',
#     'S00009479',
#     'S00009480',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CITRULLINE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
#     'S00009480',
#     'S00009481',
#     'S00009482',
#     'S00009483',
#     'S00009484',
#     'S00009486',
#     'S00009488',
#     'S00009489',
#     'S00009490',
#     'S00009492',
#     'S00009493',
#     'S00009494',
#     'S00009495',
#     'S00009496',
#     'S00009497',
#     'S00009498',
#     'S00009499',
#     'S00009500',
#     'S00009501',
#     'S00009502',
#     'S00009503',
#     'S00009504',
#     'S00009505',
#     'S00009507',
#     'S00009508',
#     'S00009509',
#     'S00009510',
#     'S00009511',
#     'S00009512',
#     'S00009513',
#     'S00009514'}}},
#  'CORTICOSTERONE': {'ST000017': {'AN000035': {'S00009470',
#     'S00009471',
#     'S00009472',
#     'S00009473',
#     'S00009474',
#     'S00009475',
#     'S00009477',
#     'S00009478',
# ...
#     'Control_4S',
#     'Test_2P',
#     'Test_2S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetyl-D-glucosamine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetylglutamic acid': {'ST000040': {'AN000060': {'Control_3P',
#     'Control_3S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetylglutamine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S'}}},
#  'N-Acetylhistidine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetyl-L-aspartic acid': {'ST000040': {'AN000060': {'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetyl-L-methionine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetylornithine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetylserotonin': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Carbamoylputrescine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Neurine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N^-Formylkynurenine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-gamma-L-Glutamyl-L-methionine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Niacinamide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Niazimin A': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Nicotinamide ribotide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Nicotinic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Isobutyl-2_4_8_10_12-tetradecapentaenamide': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'N-Methylcalystegine C1': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S'}}},
#  'Norfuraneol': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Ophthalmic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Ornithine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S'}}},
#  'Oxitriptan': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Oxoglutaric acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Test_3P',
#     'Test_3S'}}},
#  'Palmitoleoyl Ethanolamide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pantetheine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S'}}},
#  'Pantothenic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'p-Cresol glucuronide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pectic acid': {'ST000040': {'AN000060': {'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Penbutolol': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pentobarbital': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Phaseolic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Phenylpyruvic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Phlorin': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Phosphodimethylethanolamine': {'ST000040': {'AN000060': {'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pipecolic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Piperidine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pirbuterol': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Porphobilinogen': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pramipexole': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Proline betaine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Prolylhydroxyproline': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Propionylcarnitine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pterin': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pteroside B': {'ST000040': {'AN000060': {'Control_3P', 'Control_3S'}}},
#  'Putrescine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pyridine N-oxide glucuronide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pyridoxal': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pyridoxal 5^-phosphate': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pyroglutamic acid': {'ST000040': {'AN000060': {'Control_1S',
#     'Control_2S',
#     'Control_3S',
#     'Control_4S',
#     'Test_1S',
#     'Test_2S',
#     'Test_3S',
#     'Test_4S'}}},
#  '(S)-2_3_4_5-tetrahydropyridine-2-carboxylate': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(S)-4-Hydroxymandelonitrile': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(x)-1_2-Propanediol 1-O-b-D-glucopyranoside': {'ST000040': {'AN000060': {'Control_4P',
#     'Control_4S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(+)-2,3-Dihydro-3-methyl-1H-pyrrole': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Methylthiazolidine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S'}}},
#  '(S)-2,3,4,5-tetrahydropyridine-2-carboxylate': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(x)-1,2-Propanediol 1-O-b-D-glucopyranoside': {'ST000040': {'AN000060': {'Control_4P',
#     'Control_4S',
#     'Test_4P',
#     'Test_4S'}}},
#  '1,2,3-Trihydroxybenzene': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '1,2-Dihydroxy-3-keto-5-methylthiopentene': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '1,7-Dimethylguanosine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '2,6 Dimethylheptanoyl carnitine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  "3,3'-Thiobispropanoic acid": {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3,4-Methylenedioxyamphetamine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3-Hydroxy-2-methyl-[R-(R,S)]-butanoic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  "5'-Methylthioadenosine": {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '6-Acetyl-1,2,3,4-tetrahydropyridine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  "Cytidine 2',3'-cyclic phosphate": {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'LysoPC(18:2(9Z,12Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:2(11Z,14Z))': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:3(5Z,8Z,11Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:4(5Z,8Z,11Z,14Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/18:2(9Z,12Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/20:5(5Z,8Z,11Z,14Z,17Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'N6,N6,N6-Trimethyl-L-lysine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S'}}},
#  "N'-Formylkynurenine": {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Isobutyl-2,4,8,10,12-tetradecapentaenamide': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  "Pyridoxal 5'-phosphate": {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}}}

# %% [raw]
# * Extracting metabolite information from multiple ``mwTab`` files using regualar expressions:

# %%
from mwtab.mwextract import extract_metabolites, generate_matchers
from mwtab import read_files

mwtab_gen = read_files(
    "ST000017_AN000035.txt",
    "ST000040_AN000060.txt"
)

matchers = generate_matchers([
    ("ST:STUDY_TYPE",
    r"(LC-MS)")
])
extract_metabolites(mwtab_gen, matchers)
# Out:
# {'10-Formyltetrahydrofolate': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '1_2_3-Trihydroxybenzene': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '1_2-Dihydroxy-3-keto-5-methylthiopentene': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '1_7-Dimethylguanosine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '1-Aminocyclopropanecarboxylic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '1-Cyano-2-hydroxy-3-butene': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '1H-Indole-3-carboxaldehyde': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '1-Methylguanosine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '1-Methylhistidine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '1-Methylinosine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '(-)-1-Methylpropyl 1-propenyl disulfide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_2P',
#     'Control_3P',
#     'Control_4P',
#     'Test_1P',
#     'Test_2P',
#     'Test_3P',
#     'Test_4P'}}},
#  '1-Pyrroline': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '1-Pyrroline-2-carboxylic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(+)-2_3-Dihydro-3-methyl-1H-pyrrole': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2_6 Dimethylheptanoyl carnitine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Aminobenzoic acid': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Aminomuconic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Aminonaphthalene': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '2-Benzoxazolol': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '2-Furancarboxaldehyde': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Furanmethanethiol': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '2-Hydroxyadipic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Hydroxyfelbamate': {'ST000040': {'AN000060': {'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Keto-6-acetamidocaproate': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Keto-glutaramic acid': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '2-Methylbutyroylcarnitine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(±)-2-Methylthiazolidine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S'}}},
#  '2-Octenoylcarnitine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '2-Oxoarginine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S'}}},
#  '2-Phenylacetamide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '2-Pyrrolidinone': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '(2R)-2-Hydroxy-2-methylbutanenitrile': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Undecyl-4(1H)-quinolinone': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '3_3^-Thiobispropanoic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3_4-Methylenedioxyamphetamine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3-Amino-2-piperidone': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S'}}},
#  '3-Dehydrocarnitine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3-Dehydroxycarnitine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S'}}},
#  '3-Hydroxy-2-methyl-[R-(R_S)]-butanoic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '3-Hydroxyanthranilic acid': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '3-Hydroxydodecanedioic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3-Hydroxysebacic acid': {'ST000040': {'AN000060': {'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3-Methyladenine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3-Methylguanine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3-Methyl sulfolene': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '4a-Carbinolamine tetrahydrobiopterin': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_3P',
#     'Control_3S',
#     'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '4-Amino-1-piperidinecarboxylic acid': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  
': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Hydroxyvalerylcarnitine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Hypoxanthine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'icas16': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Indole': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Indoleacrylic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Inosine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S'}}},
#  'Inositol cyclic phosphate': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Isoleucyl-Tyrosine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Isoleucyl-Valine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Itaconic acid': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'L-Acetopine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Acetylcarnitine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Arginine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Asparagine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Aspartate-semialdehyde': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Aspartic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Carnitine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Coprine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Levetiracetam': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Glutamic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S'}}},
#  'L-Glutamine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Histidine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Linoleoyl ethanolamide': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'L-Kynurenine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'L-Leucine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-L-Homoglutathione': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'L-Lysine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Malic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Methionine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Lotaustralin': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'L-Phenylalanine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Proline': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Threonine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Thyronine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S'}}},
#  'L-Tryptophan': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Tyrosine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'L-Valine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'LysoPC(14:0)': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(14:1(9Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(15:0)': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(17:0)': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(18:0)': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(18:1(9Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(18:2(9Z_12Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:1(11Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:2(11Z_14Z))': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:3(5Z_8Z_11Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:4(5Z_8Z_11Z_14Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/14:0)': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/14:1(9Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/16:0)': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/16:1(9Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/18:1(11Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/18:2(9Z_12Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/20:1(11Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/20:5(5Z_8Z_11Z_14Z_17Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/22:1(13Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Maleic acid homopolymer': {'ST000040': {'AN000060': {'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Methionine sulfoximine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Methionyl-Serine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Mevalonic acid-5P': {'ST000040': {'AN000060': {'Control_1P', 'Control_1S'}}},
#  'N1-Acetylspermidine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'N-(1-Deoxy-1-fructosyl)phenylalanine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'N-(1-Deoxy-1-fructosyl)tryptophan': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
# ...
#     'Control_4S',
#     'Test_2P',
#     'Test_2S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetyl-D-glucosamine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetylglutamic acid': {'ST000040': {'AN000060': {'Control_3P',
#     'Control_3S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetylglutamine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S'}}},
#  'N-Acetylhistidine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetyl-L-aspartic acid': {'ST000040': {'AN000060': {'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetyl-L-methionine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetylornithine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Acetylserotonin': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Carbamoylputrescine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Neurine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N^-Formylkynurenine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-gamma-L-Glutamyl-L-methionine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Niacinamide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Niazimin A': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Nicotinamide ribotide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Nicotinic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Isobutyl-2_4_8_10_12-tetradecapentaenamide': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'N-Methylcalystegine C1': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S'}}},
#  'Norfuraneol': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Ophthalmic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Ornithine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S'}}},
#  'Oxitriptan': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Oxoglutaric acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Test_3P',
#     'Test_3S'}}},
#  'Palmitoleoyl Ethanolamide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pantetheine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S'}}},
#  'Pantothenic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'p-Cresol glucuronide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pectic acid': {'ST000040': {'AN000060': {'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Penbutolol': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pentobarbital': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Phaseolic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Phenylpyruvic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Phlorin': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Phosphodimethylethanolamine': {'ST000040': {'AN000060': {'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pipecolic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Piperidine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pirbuterol': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Porphobilinogen': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pramipexole': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Proline betaine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Prolylhydroxyproline': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Propionylcarnitine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pterin': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pteroside B': {'ST000040': {'AN000060': {'Control_3P', 'Control_3S'}}},
#  'Putrescine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pyridine N-oxide glucuronide': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pyridoxal': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'Pyridoxal 5^-phosphate': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'Pyroglutamic acid': {'ST000040': {'AN000060': {'Control_1S',
#     'Control_2S',
#     'Control_3S',
#     'Control_4S',
#     'Test_1S',
#     'Test_2S',
#     'Test_3S',
#     'Test_4S'}}},
#  '(S)-2_3_4_5-tetrahydropyridine-2-carboxylate': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(S)-4-Hydroxymandelonitrile': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(x)-1_2-Propanediol 1-O-b-D-glucopyranoside': {'ST000040': {'AN000060': {'Control_4P',
#     'Control_4S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(+)-2,3-Dihydro-3-methyl-1H-pyrrole': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '2-Methylthiazolidine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_3P',
#     'Test_3S'}}},
#  '(S)-2,3,4,5-tetrahydropyridine-2-carboxylate': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '(x)-1,2-Propanediol 1-O-b-D-glucopyranoside': {'ST000040': {'AN000060': {'Control_4P',
#     'Control_4S',
#     'Test_4P',
#     'Test_4S'}}},
#  '1,2,3-Trihydroxybenzene': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '1,2-Dihydroxy-3-keto-5-methylthiopentene': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '1,7-Dimethylguanosine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '2,6 Dimethylheptanoyl carnitine': {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  "3,3'-Thiobispropanoic acid": {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3,4-Methylenedioxyamphetamine': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  '3-Hydroxy-2-methyl-[R-(R,S)]-butanoic acid': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  "5'-Methylthioadenosine": {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  '6-Acetyl-1,2,3,4-tetrahydropyridine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  "Cytidine 2',3'-cyclic phosphate": {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'LysoPC(18:2(9Z,12Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:2(11Z,14Z))': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:3(5Z,8Z,11Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPC(20:4(5Z,8Z,11Z,14Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/18:2(9Z,12Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'LysoPE(0:0/20:5(5Z,8Z,11Z,14Z,17Z))': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  'N6,N6,N6-Trimethyl-L-lysine': {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S',
#     'Test_1P',
#     'Test_1S'}}},
#  "N'-Formylkynurenine": {'ST000040': {'AN000060': {'Test_1P',
#     'Test_1S',
#     'Test_2P',
#     'Test_2S',
#     'Test_3P',
#     'Test_3S',
#     'Test_4P',
#     'Test_4S'}}},
#  'N-Isobutyl-2,4,8,10,12-tetradecapentaenamide': {'ST000040': {'AN000060': {'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}},
#  "Pyridoxal 5'-phosphate": {'ST000040': {'AN000060': {'Control_1P',
#     'Control_1S',
#     'Control_2P',
#     'Control_2S',
#     'Control_3P',
#     'Control_3S',
#     'Control_4P',
#     'Control_4S'}}}}

# %% [raw]
# Converting mwTab Files
# ----------------------
#
# ``mwTab`` files can be converted between the ``mwTab`` file format and their ``JSON``
# representation using the :mod:`mwtab.converter` module.
#
# One-to-one file conversions
# ***************************
#
# * Converting from the ``mwTab`` file format into its equivalent ``JSON`` file format:

# %%
from mwtab.converter import Converter

# Using valid ANALYSIS_ID to access file from URL: from_path="1"
converter = Converter(from_path="35", to_path="out/ST000017_AN000035.json",
                      from_format="mwtab", to_format="json")
converter.convert()

# %% [raw]
# * Converting from JSON file format back to ``mwTab`` file format:

# %%
from mwtab.converter import Converter

converter = Converter(from_path="out/ST000017_AN000035.json", to_path="out/ST000017_AN000035.txt",
                      from_format="json", to_format="mwtab")
converter.convert()

# %% [raw]
# Many-to-many files conversions
# ******************************
#
# * Converting from the directory of ``mwTab`` formatted files into their equivalent
#   ``JSON`` formatted files:

# %%
from mwtab.converter import Converter

converter = Converter(from_path="mwfiles_dir_mwtab",
                      to_path="out/mwfiles_dir_json",
                      from_format="mwtab",
                      to_format="json")
converter.convert()

# %% [raw]
# * Converting from the directory of ``JSON`` formatted files into their equivalent
#   ``mwTab`` formatted files:

# %%
from mwtab.converter import Converter

converter = Converter(from_path="out/mwfiles_dir_json",
                      to_path="out/mwfiles_dir_mwtab",
                      from_format="json",
                      to_format="mwtab")
converter.convert()

# %% [raw]
# .. note:: Many-to-many files and one-to-one file conversions are available.
#           See :mod:`mwtab.converter` for full list of available conversions.

# %% [raw]
# Command-Line Interface
# ~~~~~~~~~~~~~~~~~~~~~~
#
# The mwtab Command-Line Interface provides the following functionality:
#    * Convert from the ``mwTab`` file format into its equivalent ``JSON`` file format and vice versa.
#    * Download files through Metabolomics Workbench's REST API.
#    * Validate the ``mwTab`` formatted file.

# %%
! mwtab --help
# Out:
# The mwtab command-line interface
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Usage:
#     mwtab -h | --help
#     mwtab --version
#     mwtab convert (<from-path> <to-path>) [--from-format=<format>] [--to-format=<format>] [--validate] [--mw-rest=<url>] [--verbose]
#     mwtab validate <from-path> [--mw-rest=<url>] [--verbose]
#     mwtab download url <url> [--to-path=<path>] [--verbose]
#     mwtab download study all [--to-path=<path>] [--input-item=<item>] [--output-format=<format>] [--mw-rest=<url>] [--validate] [--verbose]
#     mwtab download study <input-value> [--to-path=<path>] [--input-item=<item>] [--output-item=<item>] [--output-format=<format>] [--mw-rest=<url>] [--validate] [--verbose]
#     mwtab download (study | compound | refmet | gene | protein) <input-item> <input-value> <output-item> [--output-format=<format>] [--to-path=<path>] [--mw-rest=<url>] [--verbose]
#     mwtab download moverz <input-item> <m/z-value> <ion-type-value> <m/z-tolerance-value> [--to-path=<path>] [--mw-rest=<url>] [--verbose]
#     mwtab download exactmass <LIPID-abbreviation> <ion-type-value> [--to-path=<path>] [--mw-rest=<url>] [--verbose]
#     mwtab extract metadata <from-path> <to-path> <key> ... [--to-format=<format>] [--no-header]
#     mwtab extract metabolites <from-path> <to-path> (<key> <value>) ... [--to-format=<format>] [--no-header]
#
# Options:
#     -h, --help                      Show this screen.
#     --version                       Show version.
#     --verbose                       Print what files are processing.
#     --validate                      Validate the mwTab file.
#     --from-format=<format>          Input file format, available formats: mwtab, json [default: mwtab].
#     --to-format=<format>            Output file format [default: json].
#                                     Available formats for convert:
#                                         mwtab, json.
#                                     Available formats for extract:
#                                         json, csv.
#     --mw-rest=<url>                 URL to MW REST interface
#                                     [default: https://www.metabolomicsworkbench.org/rest/].
#     --context=<context>             Type of resource to access from MW REST interface, available contexts: study,
#                                     compound, refmet, gene, protein, moverz, exactmass [default: study].
#     --input-item=<item>             Item to search Metabolomics Workbench with.
#     --output-item=<item>            Item to be retrieved from Metabolomics Workbench.
#     --output-format=<format>        Format for item to be retrieved in, available formats: mwtab, json [default: json]
#     --no-header                     Include header at the top of csv formatted files.
#
#     For extraction <to-path> can take a "-" which will use stdout.

# %% [raw]
# Converting ``mwTab`` files in bulk
# ----------------------------------
#
# CLI one-to-one file conversions
# *******************************
#
# * Convert from a local file in ``mwTab`` format to a local file in ``JSON`` format:

# %%
! mwtab convert ST000017_AN000035.txt out/ST000017_AN000035.json \
          --from-format=mwtab --to-format=json

# %% [raw]
# * Convert from a local file in ``JSON`` format to a local file in ``mwTab`` format:

# %%
! mwtab convert ST000017_AN000035.json out/ST000017_AN000035.txt \
          --from-format=json --to-format=mwtab

# %% [raw]
# * Convert from a compressed local file in ``mwTab`` format to a compressed local file in ``JSON`` format:

# %%
! mwtab convert ST000017_AN000035.txt.gz out/ST000017_AN000035.json.gz \
          --from-format=mwtab --to-format=json

# %% [raw]
# * Convert from a compressed local file in ``JSON`` format to a compressed local file in ``mwTab`` format:

# %%
! mwtab convert ST000017_AN000035.json.gz out/ST000017_AN000035.txt.gz \
          --from-format=json --to-format=mwtab

# %% [raw]
# * Convert from a uncompressed URL file in ``mwTab`` format to a compressed local file in ``JSON`` format:

# %%
! mwtab convert 35 out/ST000017_AN000035.json.bz2 \
          --from-format=mwtab --to-format=json

# %% [raw]
# .. note:: See :mod:`mwtab.converter` for full list of available conversions.

# %% [raw]
# CLI Many-to-many files conversions
# **********************************
#
# * Convert from a directory of files in ``mwTab`` format to a directory of files in ``JSON`` format:

# %%
! mwtab convert mwfiles_dir_mwtab out/mwfiles_dir_json \
          --from-format=mwtab --to-format=json

# %% [raw]
# * Convert from a directory of files in ``JSON`` format to a directory of files in ``mwTab`` format:

# %%
! mwtab convert mwfiles_dir_json out/mwfiles_dir_mwtab \
          --from-format=json --to-format=mwtab

# %% [raw]
# * Convert from a directory of files in ``mwTab`` format to a zip archive of files in ``JSON`` format:

# %%
! mwtab convert mwfiles_dir_mwtab out/mwfiles_json.zip \
          --from-format=mwtab --to-format=json

# %% [raw]
# * Convert from a compressed tar archive of files in ``JSON`` format to a directory of files in ``mwTab`` format:

# %%
! mwtab convert mwfiles_json.tar.gz out/mwfiles_dir_mwtab \
          --from-format=json --to-format=mwtab

# %% [raw]
# * Convert from a zip archive of files in ``mwTab`` format to a compressed tar archive of files in ``JSON`` format:

# %%
! mwtab convert mwfiles_mwtab.zip out/mwfiles_json.tar.bz2 \
          --from-format=mwtab --to-format=json

# %% [raw]
# .. note:: See :mod:`mwtab.converter` for full list of available conversions.

# %% [raw]
# Download files through Metabolomics Workbenchs REST API
# ------------------------------------------------------
#
# The :mod:`mwtab` package provides the :mod:`mwtab.mwrest` module which contains a number of functions and classes for working with Metabolomics Workbenchs REST API.
#
# .. note::
#     For full official REST API specification see the following link (``MW REST API (v1.0, 5/7/2019)``):
#     https://www.metabolomicsworkbench.org/tools/MWRestAPIv1.0.pdf
#
# Download by URL
# ***************
#
# * To download a file based on a given url simply call the ``download url`` command with the desired URL and provide an output path:

# %%
! mwtab download url "https://www.metabolomicsworkbench.org/rest/study/analysis_id/AN000035/mwtab/txt"

# %% [raw]
# * To download single mwtab files simply call the ``download study`` and specifiy the analysis or study id:

# %%
! mwtab download study AN000035
! mwtab download study ST000017

# %% [raw]
# .. note::
#     It is possible to validate downloaded files by adding the ``--validate`` option to the command line.

# %% [raw]
# Download study, compound, refmet, gene, and protein files
# *********************************************************
#
# * To download study, compound, refmet, gene, and protein context files call the ``download`` command and specify the context, input iten, input value, and output item (optionally specifiy the output format).

# %%
! mwtab download study analysis_id AN000035 mwtab --output-format=txt
! mwtab download compound regno 11 name
! mwtab download refmet name Cholesterol all
! mwtab download gene gene_symbol acaca all
! mwtab download protein uniport_id Q13085 all

# %% [raw]
# Download all ``mwTab`` formatted files
# **********************************
#
# The :mod:`mwTab` package provides contains a number of command line functions for downloading Metabolomics ``mwtab`` formatted files through the Workbenchs REST API.
#
# * To download all available analysis files simply call the ``download study all`` command and provide an output path:
#
# ! mwtab download study all
#
# * It is also possible to download all study files by calling the ``download study all`` command and providing a input item an output path:
#
# ! mwtab download study all --input-item=study_id

# %% [raw]
# Download moverz and exactmass
# *****************************
#
# * To download moverz files call the ``download moverz`` command and specify the input value (LIPIDS, MB, or REFMET), m/z value, ion type value, and m/z tolerance value.

# %%
! mwtab download moverz MB 635.52 M+H 0.5 txt

# %% [raw]
# * To download exactmass files call the ``download exactmass`` command and specify the LIPID abbreviation and ion type value.

# %%
! mwtab download exactmass "PC(34:1)" M+H

# %% [raw]
# .. note::
#     It is not necissary to specify an output format for exactmass files.
#
# Extracting metabolite data nd metadata from ``mwTab`` files
# -----------------------------------------------------------
#
# The :mod:`mwtab` package provides the :func:`~mwtab.mwextract.extract_metabolites` and :func:`~mwtab.mwextract.extract_metadata` functions that can parse ``mwTab`` formatted files. The :func:`~mwtab.mwextract.extract_metabolites` takes a source (list of ``mwTab`` file) and list of metadata key-value pairs which are used to search for ``mwTab`` files which contain the given metadata pairs. The :func:`~mwtab.mwextract.extract_metadata` takes a source (list of ``mwTab`` file) and list of metadata keys which are used to search the ``mwTab`` files for possible values to the given keys.
#
# * To extract metabolite from ``mwTab`` files in a directory call the ``extract metabolites`` command and provide a list of metadata key value pairs along with a output path and output format:

# %%
! extract metabolites mwfiles_dir_mwtab output_file.csv SU:SUBJECT_TYPE Plant --to-format=csv

# %% [raw]
# .. note::
#     It is possible to use ReGeXs to match the metadata value (eg. ... SU:SUBJECT_TYPE "r'(Plant)'").
#
# * To extract metadata from ``mwTab`` files in a directory call the ``extract metadata`` command and provide a list of metadata keys along with a output path and output format:

# %%
! mwtab extract metadata mwfiles_dir_json output_file.json SUBJECT_TYPE --to-format=json

# %% [raw]
# Validating ``mwTab`` files
# --------------------------
#
# The :mod:`mwtab` package provides the :func:`~mwtab.validator.validate_file` function
# that can validate files based on a ``JSON`` schema definition. The :mod:`mwtab.mwschema`
# contains schema definitions for every block of ``mwTab`` formatted file, i.e.
# it lists the types of attributes (e.g. :py:class:`str` as well as specifies which keys are
# optional and which are required).
#
# * To validate file(s) simply call the ``validate`` command and provide path to file(s):

# %%
! mwtab validate 35
